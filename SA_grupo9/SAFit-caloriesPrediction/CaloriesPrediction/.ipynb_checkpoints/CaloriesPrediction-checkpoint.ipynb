# %% [markdown]
# ## Attribute Information
# ##### 1. HRmean: média da fraquência cardíaca durante a atividade
# ##### 2. HRmax: máximo da fraquência cardíaca durante a atividade
# ##### 3. HRmin: mínimo da fraquência cardíaca durante a atividade
# ##### 4. Active Minutes: minutos ativos
# ##### 5. Steps: passos dados
# ##### 6. Distance: distancia percorrida em metros
# ##### 7. Calories: calorias perdidas (label)

# %% [markdown]
# ## Criação do Dataset

# %%
import sklearn as skl
import pandas as pd
import numpy as np    
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import LabelEncoder

# %%
df = pd.read_csv("Datasets/dataset.csv")

# %% [markdown]
# ## Exploração de Dados

# %%
df.columns
# Out:
# Index(['Hrmean', 'Hrmax', 'Hrmin', 'StartIntervalHR', 'EndIntervalHR',
#        'ActiveMinutes', 'StartIntervalAM', 'EndIntervalAm', 'Calories',
#        'StartIntervalC', 'EndIntervalC', 'Steps', 'StartIntervalS',
#        'EndIntervalS', 'Distance'],
#       dtype='object')

# %%
df.head()
# Out:
#    Hrmean  Hrmax  Hrmin                StartIntervalHR  \
# 0      75    123     47  2020-04-30T00:07:00.000+01:00
# 1      85    139     59  2020-05-01T00:03:00.000+01:00
# 2      73    166     52  2020-05-03T13:50:00.000+01:00
# 3      70    106     48  2020-05-04T08:36:00.000+01:00
# 4      73    160     48  2020-05-05T08:50:00.000+01:00
#
#                    EndIntervalHR  ActiveMinutes  \
# 0  2020-04-30T18:53:00.000+01:00             25
# 1  2020-05-01T21:51:00.000+01:00             34
# 2  2020-05-03T21:07:00.000+01:00            119
# 3  2020-05-04T22:44:00.000+01:00             18
# 4  2020-05-05T23:51:00.000+01:00             15
#
#                  StartIntervalAM                  EndIntervalAm  Calories  \
# 0  2020-04-30T00:00:00.000+01:00  2020-05-01T00:00:00.000+01:00      2279
# 1  2020-05-01T00:00:00.000+01:00  2020-05-02T00:00:00.000+01:00      2344
# 2  2020-05-03T00:00:00.000+01:00  2020-05-04T00:00:00.000+01:00      1783
# 3  2020-05-04T00:00:00.000+01:00  2020-05-05T00:00:00.000+01:00      2181
# 4  2020-05-05T00:00:00.000+01:00  2020-05-06T00:00:00.000+01:00      2225
#
#                   StartIntervalC                   EndIntervalC  Steps  \
# 0  2020-04-30T00:06:01.415+01:00  2020-04-30T23:52:31.521+01:00   3294
# 1  2020-05-01T00:02:35.056+01:00  2020-05-01T21:50:54.268+01:00   2776
# 2  2020-05-03T00:01:00.000+01:00  2020-05-03T21:15:50.075+01:00   7167
# 3  2020-05-04T00:12:53.239+01:00  2020-05-04T23:58:30.124+01:00   3779
# 4  2020-05-05T08:49:40.429+01:00  2020-05-05T23:54:30.337+01:00   2001
#
#                   StartIntervalS                   EndIntervalS  Distance
# 0  2020-04-30T00:07:01.415+01:00  2020-04-30T23:39:00.000+01:00      2636
# 1  2020-05-01T00:03:35.056+01:00  2020-05-01T21:50:21.245+01:00      3276
# 2  2020-05-03T00:01:00.000+01:00  2020-05-03T21:15:50.075+01:00      5553
# 3  2020-05-04T00:13:53.239+01:00  2020-05-04T23:58:30.124+01:00      3242
# 4  2020-05-05T00:01:00.000+01:00  2020-05-05T23:54:30.337+01:00      2271

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 453 entries, 0 to 452
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Hrmean           453 non-null    int64
#  1   Hrmax            453 non-null    int64
#  2   Hrmin            453 non-null    int64
#  3   StartIntervalHR  453 non-null    object
#  4   EndIntervalHR    453 non-null    object
#  5   ActiveMinutes    453 non-null    int64
#  6   StartIntervalAM  453 non-null    object
#  7   EndIntervalAm    453 non-null    object
#  8   Calories         453 non-null    int64
#  9   StartIntervalC   453 non-null    object
#  10  EndIntervalC     453 non-null    object
#  11  Steps            453 non-null    int64
#  12  StartIntervalS   453 non-null    object
#  13  EndIntervalS     453 non-null    object
#  14  Distance         453 non-null    int64
# dtypes: int64(7), object(8)
# memory usage: 53.2+ KB

# %%
df = df.drop(['StartIntervalHR', 'EndIntervalHR', 'StartIntervalAM', 'EndIntervalAm', 'StartIntervalC', 'EndIntervalC', 'StartIntervalS', 'EndIntervalS'], axis=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 453 entries, 0 to 452
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Hrmean         453 non-null    int64
#  1   Hrmax          453 non-null    int64
#  2   Hrmin          453 non-null    int64
#  3   ActiveMinutes  453 non-null    int64
#  4   Calories       453 non-null    int64
#  5   Steps          453 non-null    int64
#  6   Distance       453 non-null    int64
# dtypes: int64(7)
# memory usage: 24.9 KB

# %%
df.head()
# Out:
#    Hrmean  Hrmax  Hrmin  ActiveMinutes  Calories  Steps  Distance
# 0      75    123     47             25      2279   3294      2636
# 1      85    139     59             34      2344   2776      3276
# 2      73    166     52            119      1783   7167      5553
# 3      70    106     48             18      2181   3779      3242
# 4      73    160     48             15      2225   2001      2271

# %%
df.describe()
# Out:
#            Hrmean       Hrmax       Hrmin  ActiveMinutes     Calories  \
# count  453.000000  453.000000  453.000000     453.000000   453.000000
# mean    72.333333  128.730684   46.545254      73.622517  1967.682119
# std      5.042006   17.316621    5.672149      68.486522   260.376107
# min     54.000000   84.000000   40.000000       2.000000   763.000000
# 25%     69.000000  119.000000   43.000000      26.000000  1832.000000
# 50%     71.000000  126.000000   47.000000      57.000000  1927.000000
# 75%     75.000000  135.000000   48.000000      98.000000  2070.000000
# max     96.000000  195.000000   71.000000     543.000000  3150.000000
#
#               Steps      Distance
# count    453.000000    453.000000
# mean    5154.335541   4050.713024
# std     4470.062006   3500.503973
# min       71.000000     15.000000
# 25%     2007.000000   1480.000000
# 50%     3823.000000   3027.000000
# 75%     7274.000000   5762.000000
# max    36760.000000  25633.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 453 entries, 0 to 452
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Hrmean         453 non-null    int64
#  1   Hrmax          453 non-null    int64
#  2   Hrmin          453 non-null    int64
#  3   ActiveMinutes  453 non-null    int64
#  4   Calories       453 non-null    int64
#  5   Steps          453 non-null    int64
#  6   Distance       453 non-null    int64
# dtypes: int64(7)
# memory usage: 24.9 KB

# %%
df.isna().any()
# Out:
# Hrmean           False
# Hrmax            False
# Hrmin            False
# ActiveMinutes    False
# Calories         False
# Steps            False
# Distance         False
# dtype: bool

# %%
df = df.dropna()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 453 entries, 0 to 452
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Hrmean         453 non-null    int64
#  1   Hrmax          453 non-null    int64
#  2   Hrmin          453 non-null    int64
#  3   ActiveMinutes  453 non-null    int64
#  4   Calories       453 non-null    int64
#  5   Steps          453 non-null    int64
#  6   Distance       453 non-null    int64
# dtypes: int64(7)
# memory usage: 28.3 KB

# %%
df.isna().any()
# Out:
# Hrmean           False
# Hrmax            False
# Hrmin            False
# ActiveMinutes    False
# Calories         False
# Steps            False
# Distance         False
# dtype: bool

# %%
obj_cols = []
num_cols = []
for col in df.columns:
    if df[col].dtype == 'object':
        obj_cols.append(col)
    else:
        num_cols.append(col)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 453 entries, 0 to 452
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Hrmean         453 non-null    int64
#  1   Hrmax          453 non-null    int64
#  2   Hrmin          453 non-null    int64
#  3   ActiveMinutes  453 non-null    int64
#  4   Calories       453 non-null    int64
#  5   Steps          453 non-null    int64
#  6   Distance       453 non-null    int64
# dtypes: int64(7)
# memory usage: 28.3 KB

# %% [markdown]
# #### Análise HRmax

# %%
sns.histplot(df['Hrmax'], kde=True);

# %%
print("Skewness: %f" % df['Hrmax'].skew())
print("Kurtosis: %f" %df['Hrmax'].kurt())
# Out:
# Skewness: 1.218788
# Kurtosis: 2.590170

# %% [markdown]
# #### Análise HRmean

# %%
sns.histplot(df['Hrmean'], kde=True)
# Out:
# <AxesSubplot:xlabel='Hrmean', ylabel='Count'>

# %%
print("Skewness: %f" % df['Hrmean'].skew())
print("Kurtosis: %f" %df['Hrmean'].kurt())
# Out:
# Skewness: 0.642570
# Kurtosis: 2.025181

# %% [markdown]
# #### Análise HRmin

# %%
sns.histplot(df['Hrmin'], kde=True)
# Out:
# <AxesSubplot:xlabel='Hrmin', ylabel='Count'>

# %%
print("Skewness: %f" % df['Hrmin'].skew())
print("Kurtosis: %f" %df['Hrmin'].kurt())
# Out:
# Skewness: 1.740431
# Kurtosis: 4.109109

# %% [markdown]
# #### Análise ActiveMinutes

# %%
sns.histplot(df['ActiveMinutes'], kde=True)
# Out:
# <AxesSubplot:xlabel='ActiveMinutes', ylabel='Count'>

# %%
print("Skewness: %f" % df['ActiveMinutes'].skew())
print("Kurtosis: %f" %df['ActiveMinutes'].kurt())
# Out:
# Skewness: 2.406681
# Kurtosis: 9.901005

# %% [markdown]
# #### Análise Steps

# %%
sns.histplot(df['Steps'], kde=True)
# Out:
# <AxesSubplot:xlabel='Steps', ylabel='Count'>

# %%
print("Skewness: %f" % df['Steps'].skew())
print("Kurtosis: %f" %df['Steps'].kurt())
# Out:
# Skewness: 2.079063
# Kurtosis: 7.856751

# %% [markdown]
# #### Análise Distance

# %%
sns.histplot(df['Distance'], kde=True)
# Out:
# <AxesSubplot:xlabel='Distance', ylabel='Count'>

# %%
print("Skewness: %f" % df['Distance'].skew())
print("Kurtosis: %f" %df['Distance'].kurt())
# Out:
# Skewness: 1.842350
# Kurtosis: 5.437741

# %%
corr_matrix = df.corr()
f, ax = plt.subplots(figsize=(16, 12))
sns.heatmap(corr_matrix, vmin= -1, vmax = 1, square=True, annot =True);

# %% [markdown]
# ## Preparação de Dados

# %% [markdown]
# ### Verificar Balanceamento do Dataset

# %%
sns.set_style('whitegrid')
sns.histplot(df['Calories'], kde=True)
# Out:
# <AxesSubplot:xlabel='Calories', ylabel='Count'>

# %%
sns.pairplot(df,hue="Calories");

# %% [markdown]
# ### Dados Numéricos

# %% [markdown]
# #### HRmean

# %%
''' Detection '''
# IQR
Q1 = np.percentile(df['Hrmean'], 25,
                   interpolation = 'midpoint')
 
Q3 = np.percentile(df['Hrmean'], 75,
                   interpolation = 'midpoint')
IQR = Q3 - Q1
 
print("Old Shape: ", df.shape)

''' Removing the Outliers '''
df = df[(df['Hrmean'] <= (Q3+1.5*IQR)) & (df['Hrmean'] >= (Q1-1.5*IQR))]
 
print("New Shape: ", df.shape)
# Out:
# Old Shape:  (453, 7)
# New Shape:  (440, 7)
# C:\Users\Leonardo\AppData\Local\Temp\ipykernel_3928\979904472.py:3: DeprecationWarning: the `interpolation=` argument to percentile was renamed to `method=`, which has additional options.
# Users of the modes 'nearest', 'lower', 'higher', or 'midpoint' are encouraged to review the method they. (Deprecated NumPy 1.22)
#   Q1 = np.percentile(df['Hrmean'], 25,
# C:\Users\Leonardo\AppData\Local\Temp\ipykernel_3928\979904472.py:6: DeprecationWarning: the `interpolation=` argument to percentile was renamed to `method=`, which has additional options.
# Users of the modes 'nearest', 'lower', 'higher', or 'midpoint' are encouraged to review the method they. (Deprecated NumPy 1.22)
#   Q3 = np.percentile(df['Hrmean'], 75,

# %%
ax = sns.boxplot(x=df["Hrmean"], y=df["Calories"])

# %% [markdown]
# #### HRmax

# %%
''' Detection '''
# IQR
Q1 = np.percentile(df['Hrmax'], 25,
                   interpolation = 'midpoint')
 
Q3 = np.percentile(df['Hrmax'], 75,
                   interpolation = 'midpoint')
IQR = Q3 - Q1
 
print("Old Shape: ", df.shape)

 
''' Removing the Outliers '''
df = df[(df['Hrmax'] <= (Q3+1.5*IQR)) & (df['Hrmax'] >= (Q1-1.5*IQR))]


print("New Shape: ", df.shape)
# Out:
# Old Shape:  (440, 7)
# New Shape:  (407, 7)
# C:\Users\Leonardo\AppData\Local\Temp\ipykernel_3928\374226336.py:3: DeprecationWarning: the `interpolation=` argument to percentile was renamed to `method=`, which has additional options.
# Users of the modes 'nearest', 'lower', 'higher', or 'midpoint' are encouraged to review the method they. (Deprecated NumPy 1.22)
#   Q1 = np.percentile(df['Hrmax'], 25,
# C:\Users\Leonardo\AppData\Local\Temp\ipykernel_3928\374226336.py:6: DeprecationWarning: the `interpolation=` argument to percentile was renamed to `method=`, which has additional options.
# Users of the modes 'nearest', 'lower', 'higher', or 'midpoint' are encouraged to review the method they. (Deprecated NumPy 1.22)
#   Q3 = np.percentile(df['Hrmax'], 75,

# %%
ax = sns.boxplot(x=df["Hrmax"], y=df["Calories"])

# %% [markdown]
# #### HRmin

# %%
''' Detection '''
# IQR
Q1 = np.percentile(df['Hrmin'], 25,
                   interpolation = 'midpoint')
 
Q3 = np.percentile(df['Hrmin'], 75,
                   interpolation = 'midpoint')
IQR = Q3 - Q1
 
print("Old Shape: ", df.shape)
 
''' Removing the Outliers '''
df = df[(df['Hrmin'] <= (Q3+1.5*IQR)) & (df['Hrmin'] >= (Q1-1.5*IQR))]


print("New Shape: ", df.shape)
# Out:
# Old Shape:  (407, 7)
# New Shape:  (390, 7)
# C:\Users\Leonardo\AppData\Local\Temp\ipykernel_3928\994840238.py:3: DeprecationWarning: the `interpolation=` argument to percentile was renamed to `method=`, which has additional options.
# Users of the modes 'nearest', 'lower', 'higher', or 'midpoint' are encouraged to review the method they. (Deprecated NumPy 1.22)
#   Q1 = np.percentile(df['Hrmin'], 25,
# C:\Users\Leonardo\AppData\Local\Temp\ipykernel_3928\994840238.py:6: DeprecationWarning: the `interpolation=` argument to percentile was renamed to `method=`, which has additional options.
# Users of the modes 'nearest', 'lower', 'higher', or 'midpoint' are encouraged to review the method they. (Deprecated NumPy 1.22)
#   Q3 = np.percentile(df['Hrmin'], 75,

# %%
ax = sns.boxplot(x=df["Hrmin"], y=df["Calories"])

# %% [markdown]
# #### ActiveMinutes

# %%
''' Detection '''
# IQR
Q1 = np.percentile(df['ActiveMinutes'], 25,
                   interpolation = 'midpoint')
 
Q3 = np.percentile(df['ActiveMinutes'], 75,
                   interpolation = 'midpoint')
IQR = Q3 - Q1
 
print("Old Shape: ", df.shape)
 
''' Removing the Outliers '''
df = df[(df['ActiveMinutes'] <= (Q3+1.5*IQR)) & (df['ActiveMinutes'] >= (Q1-1.5*IQR))]


print("New Shape: ", df.shape)
# Out:
# Old Shape:  (390, 7)
# New Shape:  (371, 7)
# C:\Users\Leonardo\AppData\Local\Temp\ipykernel_3928\1529398573.py:3: DeprecationWarning: the `interpolation=` argument to percentile was renamed to `method=`, which has additional options.
# Users of the modes 'nearest', 'lower', 'higher', or 'midpoint' are encouraged to review the method they. (Deprecated NumPy 1.22)
#   Q1 = np.percentile(df['ActiveMinutes'], 25,
# C:\Users\Leonardo\AppData\Local\Temp\ipykernel_3928\1529398573.py:6: DeprecationWarning: the `interpolation=` argument to percentile was renamed to `method=`, which has additional options.
# Users of the modes 'nearest', 'lower', 'higher', or 'midpoint' are encouraged to review the method they. (Deprecated NumPy 1.22)
#   Q3 = np.percentile(df['ActiveMinutes'], 75,

# %%
ax = sns.boxplot(x=df["ActiveMinutes"], y=df["Calories"])

# %% [markdown]
# #### Steps

# %%
''' Detection '''
# IQR
Q1 = np.percentile(df['Steps'], 25,
                   interpolation = 'midpoint')
 
Q3 = np.percentile(df['Steps'], 75,
                   interpolation = 'midpoint')
IQR = Q3 - Q1
 
print("Old Shape: ", df.shape)
 
''' Removing the Outliers '''
df = df[(df['Steps'] <= (Q3+1.5*IQR)) & (df['Steps'] >= (Q1-1.5*IQR))]


print("New Shape: ", df.shape)
# Out:
# Old Shape:  (371, 7)
# New Shape:  (365, 7)
# C:\Users\Leonardo\AppData\Local\Temp\ipykernel_3928\137263883.py:3: DeprecationWarning: the `interpolation=` argument to percentile was renamed to `method=`, which has additional options.
# Users of the modes 'nearest', 'lower', 'higher', or 'midpoint' are encouraged to review the method they. (Deprecated NumPy 1.22)
#   Q1 = np.percentile(df['Steps'], 25,
# C:\Users\Leonardo\AppData\Local\Temp\ipykernel_3928\137263883.py:6: DeprecationWarning: the `interpolation=` argument to percentile was renamed to `method=`, which has additional options.
# Users of the modes 'nearest', 'lower', 'higher', or 'midpoint' are encouraged to review the method they. (Deprecated NumPy 1.22)
#   Q3 = np.percentile(df['Steps'], 75,

# %%
ax = sns.boxplot(x=df["Steps"], y=df["Calories"])

# %% [markdown]
# #### Distance

# %%
''' Detection '''
# IQR
Q1 = np.percentile(df['Distance'], 25,
                   interpolation = 'midpoint')
 
Q3 = np.percentile(df['Distance'], 75,
                   interpolation = 'midpoint')
IQR = Q3 - Q1
 
print("Old Shape: ", df.shape)
 
''' Removing the Outliers '''
df = df[(df['Distance'] <= (Q3+1.5*IQR)) & (df['Distance'] >= (Q1-1.5*IQR))]


print("New Shape: ", df.shape)
# Out:
# Old Shape:  (365, 7)
# New Shape:  (363, 7)
# C:\Users\Leonardo\AppData\Local\Temp\ipykernel_3928\94742952.py:3: DeprecationWarning: the `interpolation=` argument to percentile was renamed to `method=`, which has additional options.
# Users of the modes 'nearest', 'lower', 'higher', or 'midpoint' are encouraged to review the method they. (Deprecated NumPy 1.22)
#   Q1 = np.percentile(df['Distance'], 25,
# C:\Users\Leonardo\AppData\Local\Temp\ipykernel_3928\94742952.py:6: DeprecationWarning: the `interpolation=` argument to percentile was renamed to `method=`, which has additional options.
# Users of the modes 'nearest', 'lower', 'higher', or 'midpoint' are encouraged to review the method they. (Deprecated NumPy 1.22)
#   Q3 = np.percentile(df['Distance'], 75,

# %%
ax = sns.boxplot(x=df["Distance"], y=df["Calories"])

# %% [markdown]
# ## Modelos

# %% [markdown]
# #### Separação Treino Teste

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 363 entries, 0 to 452
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Hrmean         363 non-null    int64
#  1   Hrmax          363 non-null    int64
#  2   Hrmin          363 non-null    int64
#  3   ActiveMinutes  363 non-null    int64
#  4   Calories       363 non-null    int64
#  5   Steps          363 non-null    int64
#  6   Distance       363 non-null    int64
# dtypes: int64(7)
# memory usage: 30.8 KB

# %%
X = df.drop(['Calories'], axis=1)
y = df['Calories'].to_frame()

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler

# %matplotlib inline

X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.25, random_state=2022)

# %%
sns.displot(df["Calories"], kde=True)

# %%
sns.pairplot(df)

# %% [markdown]
# ### Regressão Linear

# %% [markdown]
# #### Treino e Previsão

# %%
from sklearn.linear_model import LinearRegression
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import KFold

# %%
model = make_pipeline(StandardScaler(), LinearRegression())
params= {}

# %%
grid = GridSearchCV(model,params, cv=KFold(n_splits=10), n_jobs=1, verbose=2,
                    return_train_score=True, scoring='neg_mean_absolute_error', refit=True)

# %%
grid.fit(X_train,y_train)
# Out:
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# [CV] END .................................................... total time=   0.0s
# [CV] END .................................................... total time=   0.0s
# [CV] END .................................................... total time=   0.0s
# [CV] END .................................................... total time=   0.0s
# [CV] END .................................................... total time=   0.0s
# [CV] END .................................................... total time=   0.0s
# [CV] END .................................................... total time=   0.0s
# [CV] END .................................................... total time=   0.0s
# [CV] END .................................................... total time=   0.0s
# [CV] END .................................................... total time=   0.0s
# GridSearchCV(cv=KFold(n_splits=10, random_state=None, shuffle=False),
#              estimator=Pipeline(steps=[('standardscaler', StandardScaler()),
#                                        ('linearregression',
#                                         LinearRegression())]),
#              n_jobs=1, param_grid={}, return_train_score=True,
#              scoring='neg_mean_absolute_error', verbose=2)

# %%
predictions = grid.predict(X_test)
predictions
# Out:
# array([[1941.15879682],
#        [1880.10745024],
#        [1890.59781593],
#        [2058.10704183],
#        [2013.70926359],
#        [2205.44861067],
#        [2000.7532405 ],
#        [2006.45014099],
#        [1964.76962073],
#        [1945.57271741],
#        [1962.14698307],
#        [1876.31494806],
#        [1958.67128387],
#        [1881.4175479 ],
#        [2026.11330959],
#        [2031.18338308],
#        [2028.94137919],
#        [1896.29332153],
#        [1789.50282562],
#        [1823.22022537],
#        [1830.04697097],
#        [1817.91993492],
#        [2007.88837121],
#        [2084.98338207],
#        [2032.8675739 ],
#        [2112.21071887],
#        [2037.47113352],
#        [1936.65475035],
#        [1938.89168423],
#        [1943.06580652],
#        [1870.73462396],
#        [1952.59564041],
#        [1980.34995673],
#        [1903.61243771],
#        [2054.92553111],
#        [1841.84707657],
#        [2000.46631541],
#        [1939.65823108],
#        [1988.37997231],
#        [1632.77797749],
#        [1978.14983884],
#        [1892.74588001],
#        [1825.68136631],
#        [1872.729894  ],
#        [1920.21138651],
#        [1839.56418303],
#        [1854.56940344],
#        [1899.58032362],
#        [1907.40930127],
#        [1932.74963596],
#        [1844.42941115],
#        [1992.28089164],
#        [1907.69156088],
#        [1985.47345042],
#        [2018.26733165],
#        [1928.30099308],
#        [2043.73721042],
#        [1862.71622285],
#        [1748.12886259],
#        [2020.93165618],
#        [1930.5909783 ],
#        [1827.6303676 ],
#        [1915.52102652],
#        [1890.70728284],
#        [1827.22928807],
#        [1775.55785667],
#        [1811.62393979],
#        [1975.99070806],
#        [2176.95909263],
#        [1976.06584206],
#        [1959.92561854],
#        [1812.75338776],
#        [1912.20242239],
#        [1975.97837542],
#        [1866.80186069],
#        [1821.16564891],
#        [1932.97685072],
#        [2096.66595089],
#        [1805.65490552],
#        [1927.15114456],
#        [2027.1530664 ],
#        [2222.16393826],
#        [1968.87073646],
#        [1827.13211624],
#        [1870.7694178 ],
#        [1894.93220684],
#        [1988.18077767],
#        [1823.29031283],
#        [2033.25908113],
#        [1872.63949115],
#        [1757.50274923]])

# %% [markdown]
# #### Avaliação

# %%
plt.scatter(y_test, predictions)

# %%
sns.displot((y_test-predictions), kde=True)

# %%
from sklearn import metrics

# %%
print('MAE:', metrics.mean_absolute_error(y_test, predictions))
print('MSE:', metrics.mean_squared_error(y_test, predictions))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, predictions)))
# Out:
# MAE: 122.74383847185003
# MSE: 35507.89580038441
# RMSE: 188.4353889278349

# %% [markdown]
# ### Árvore de Decisão

# %% [markdown]
# #### Treino e Previsão

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
clf = DecisionTreeRegressor(random_state=2022)
params = {'criterion': ['squared_error', 'friedman_mse', 'absolute_error'],
             'min_samples_leaf': range(1,5)}

# %%
grid = GridSearchCV(clf, params, cv=KFold(n_splits=10), n_jobs=1, verbose=2, return_train_score=True, scoring='neg_mean_absolute_error', refit=True)

# %%
grid.fit(X_train,y_train)
# Out:
# Fitting 10 folds for each of 12 candidates, totalling 120 fits
# [CV] END ........criterion=squared_error, min_samples_leaf=1; total time=   0.0s
# [CV] END ........criterion=squared_error, min_samples_leaf=1; total time=   0.0s
# [CV] END ........criterion=squared_error, min_samples_leaf=1; total time=   0.0s
# [CV] END ........criterion=squared_error, min_samples_leaf=1; total time=   0.0s
# [CV] END ........criterion=squared_error, min_samples_leaf=1; total time=   0.0s
# [CV] END ........criterion=squared_error, min_samples_leaf=1; total time=   0.0s
# [CV] END ........criterion=squared_error, min_samples_leaf=1; total time=   0.0s
# [CV] END ........criterion=squared_error, min_samples_leaf=1; total time=   0.0s
# [CV] END ........criterion=squared_error, min_samples_leaf=1; total time=   0.0s
# [CV] END ........criterion=squared_error, min_samples_leaf=1; total time=   0.0s
# [CV] END ........criterion=squared_error, min_samples_leaf=2; total time=   0.0s
# [CV] END ........criterion=squared_error, min_samples_leaf=2; total time=   0.0s
# [CV] END ........criterion=squared_error, min_samples_leaf=2; total time=   0.0s
# [CV] END ........criterion=squared_error, min_samples_leaf=2; total time=   0.0s
# [CV] END ........criterion=squared_error, min_samples_leaf=2; total time=   0.0s
# [CV] END ........criterion=squared_error, min_samples_leaf=2; total time=   0.0s
# [CV] END ........criterion=squared_error, min_samples_leaf=2; total time=   0.0s
# [CV] END ........criterion=squared_error, min_samples_leaf=2; total time=   0.0s
# [CV] END ........criterion=squared_error, min_samples_leaf=2; total time=   0.0s
# [CV] END ........criterion=squared_error, min_samples_leaf=2; total time=   0.0s
# [CV] END ........criterion=squared_error, min_samples_leaf=3; total time=   0.0s
# [CV] END ........criterion=squared_error, min_samples_leaf=3; total time=   0.0s
# [CV] END ........criterion=squared_error, min_samples_leaf=3; total time=   0.0s
# [CV] END ........criterion=squared_error, min_samples_leaf=3; total time=   0.0s
# [CV] END ........criterion=squared_error, min_samples_leaf=3; total time=   0.0s
# [CV] END ........criterion=squared_error, min_samples_leaf=3; total time=   0.0s
# [CV] END ........criterion=squared_error, min_samples_leaf=3; total time=   0.0s
# [CV] END ........criterion=squared_error, min_samples_leaf=3; total time=   0.0s
# [CV] END ........criterion=squared_error, min_samples_leaf=3; total time=   0.0s
# [CV] END ........criterion=squared_error, min_samples_leaf=3; total time=   0.0s
# [CV] END ........criterion=squared_error, min_samples_leaf=4; total time=   0.0s
# [CV] END ........criterion=squared_error, min_samples_leaf=4; total time=   0.0s
# [CV] END ........criterion=squared_error, min_samples_leaf=4; total time=   0.0s
# [CV] END ........criterion=squared_error, min_samples_leaf=4; total time=   0.0s
# [CV] END ........criterion=squared_error, min_samples_leaf=4; total time=   0.0s
# [CV] END ........criterion=squared_error, min_samples_leaf=4; total time=   0.0s
# [CV] END ........criterion=squared_error, min_samples_leaf=4; total time=   0.0s
# [CV] END ........criterion=squared_error, min_samples_leaf=4; total time=   0.0s
# [CV] END ........criterion=squared_error, min_samples_leaf=4; total time=   0.0s
# [CV] END ........criterion=squared_error, min_samples_leaf=4; total time=   0.0s
# [CV] END .........criterion=friedman_mse, min_samples_leaf=1; total time=   0.0s
# [CV] END .........criterion=friedman_mse, min_samples_leaf=1; total time=   0.0s
# [CV] END .........criterion=friedman_mse, min_samples_leaf=1; total time=   0.0s
# [CV] END .........criterion=friedman_mse, min_samples_leaf=1; total time=   0.0s
# [CV] END .........criterion=friedman_mse, min_samples_leaf=1; total time=   0.0s
# [CV] END .........criterion=friedman_mse, min_samples_leaf=1; total time=   0.0s
# [CV] END .........criterion=friedman_mse, min_samples_leaf=1; total time=   0.0s
# [CV] END .........criterion=friedman_mse, min_samples_leaf=1; total time=   0.0s
# [CV] END .........criterion=friedman_mse, min_samples_leaf=1; total time=   0.0s
# [CV] END .........criterion=friedman_mse, min_samples_leaf=1; total time=   0.0s
# [CV] END .........criterion=friedman_mse, min_samples_leaf=2; total time=   0.0s
# [CV] END .........criterion=friedman_mse, min_samples_leaf=2; total time=   0.0s
# [CV] END .........criterion=friedman_mse, min_samples_leaf=2; total time=   0.0s
# [CV] END .........criterion=friedman_mse, min_samples_leaf=2; total time=   0.0s
# [CV] END .........criterion=friedman_mse, min_samples_leaf=2; total time=   0.0s
# [CV] END .........criterion=friedman_mse, min_samples_leaf=2; total time=   0.0s
# [CV] END .........criterion=friedman_mse, min_samples_leaf=2; total time=   0.0s
# [CV] END .........criterion=friedman_mse, min_samples_leaf=2; total time=   0.0s
# [CV] END .........criterion=friedman_mse, min_samples_leaf=2; total time=   0.0s
# [CV] END .........criterion=friedman_mse, min_samples_leaf=2; total time=   0.0s
# [CV] END .........criterion=friedman_mse, min_samples_leaf=3; total time=   0.0s
# [CV] END .........criterion=friedman_mse, min_samples_leaf=3; total time=   0.0s
# [CV] END .........criterion=friedman_mse, min_samples_leaf=3; total time=   0.0s
# [CV] END .........criterion=friedman_mse, min_samples_leaf=3; total time=   0.0s
# [CV] END .........criterion=friedman_mse, min_samples_leaf=3; total time=   0.0s
# [CV] END .........criterion=friedman_mse, min_samples_leaf=3; total time=   0.0s
# [CV] END .........criterion=friedman_mse, min_samples_leaf=3; total time=   0.0s
# [CV] END .........criterion=friedman_mse, min_samples_leaf=3; total time=   0.0s
# [CV] END .........criterion=friedman_mse, min_samples_leaf=3; total time=   0.0s
# [CV] END .........criterion=friedman_mse, min_samples_leaf=3; total time=   0.0s
# [CV] END .........criterion=friedman_mse, min_samples_leaf=4; total time=   0.0s
# [CV] END .........criterion=friedman_mse, min_samples_leaf=4; total time=   0.0s
# [CV] END .........criterion=friedman_mse, min_samples_leaf=4; total time=   0.0s
# [CV] END .........criterion=friedman_mse, min_samples_leaf=4; total time=   0.0s
# [CV] END .........criterion=friedman_mse, min_samples_leaf=4; total time=   0.0s
# [CV] END .........criterion=friedman_mse, min_samples_leaf=4; total time=   0.0s
# [CV] END .........criterion=friedman_mse, min_samples_leaf=4; total time=   0.0s
# [CV] END .........criterion=friedman_mse, min_samples_leaf=4; total time=   0.0s
# [CV] END .........criterion=friedman_mse, min_samples_leaf=4; total time=   0.0s
# [CV] END .........criterion=friedman_mse, min_samples_leaf=4; total time=   0.0s
# [CV] END .......criterion=absolute_error, min_samples_leaf=1; total time=   0.0s
# [CV] END .......criterion=absolute_error, min_samples_leaf=1; total time=   0.0s
# [CV] END .......criterion=absolute_error, min_samples_leaf=1; total time=   0.0s
# [CV] END .......criterion=absolute_error, min_samples_leaf=1; total time=   0.0s
# [CV] END .......criterion=absolute_error, min_samples_leaf=1; total time=   0.0s
# [CV] END .......criterion=absolute_error, min_samples_leaf=1; total time=   0.0s
# [CV] END .......criterion=absolute_error, min_samples_leaf=1; total time=   0.0s
# [CV] END .......criterion=absolute_error, min_samples_leaf=1; total time=   0.0s
# [CV] END .......criterion=absolute_error, min_samples_leaf=1; total time=   0.0s
# [CV] END .......criterion=absolute_error, min_samples_leaf=1; total time=   0.0s
# [CV] END .......criterion=absolute_error, min_samples_leaf=2; total time=   0.0s
# [CV] END .......criterion=absolute_error, min_samples_leaf=2; total time=   0.0s
# [CV] END .......criterion=absolute_error, min_samples_leaf=2; total time=   0.0s
# [CV] END .......criterion=absolute_error, min_samples_leaf=2; total time=   0.0s
# [CV] END .......criterion=absolute_error, min_samples_leaf=2; total time=   0.0s
# [CV] END .......criterion=absolute_error, min_samples_leaf=2; total time=   0.0s
# [CV] END .......criterion=absolute_error, min_samples_leaf=2; total time=   0.0s
# [CV] END .......criterion=absolute_error, min_samples_leaf=2; total time=   0.0s
# [CV] END .......criterion=absolute_error, min_samples_leaf=2; total time=   0.0s
# [CV] END .......criterion=absolute_error, min_samples_leaf=2; total time=   0.0s
# [CV] END .......criterion=absolute_error, min_samples_leaf=3; total time=   0.0s
# [CV] END .......criterion=absolute_error, min_samples_leaf=3; total time=   0.0s
# [CV] END .......criterion=absolute_error, min_samples_leaf=3; total time=   0.0s
# [CV] END .......criterion=absolute_error, min_samples_leaf=3; total time=   0.0s
# [CV] END .......criterion=absolute_error, min_samples_leaf=3; total time=   0.0s
# [CV] END .......criterion=absolute_error, min_samples_leaf=3; total time=   0.0s
# [CV] END .......criterion=absolute_error, min_samples_leaf=3; total time=   0.0s
# [CV] END .......criterion=absolute_error, min_samples_leaf=3; total time=   0.0s
# [CV] END .......criterion=absolute_error, min_samples_leaf=3; total time=   0.0s
# [CV] END .......criterion=absolute_error, min_samples_leaf=3; total time=   0.0s
# [CV] END .......criterion=absolute_error, min_samples_leaf=4; total time=   0.0s
# [CV] END .......criterion=absolute_error, min_samples_leaf=4; total time=   0.0s
# [CV] END .......criterion=absolute_error, min_samples_leaf=4; total time=   0.0s
# [CV] END .......criterion=absolute_error, min_samples_leaf=4; total time=   0.0s
# [CV] END .......criterion=absolute_error, min_samples_leaf=4; total time=   0.0s
# [CV] END .......criterion=absolute_error, min_samples_leaf=4; total time=   0.0s
# [CV] END .......criterion=absolute_error, min_samples_leaf=4; total time=   0.0s
# [CV] END .......criterion=absolute_error, min_samples_leaf=4; total time=   0.0s
# [CV] END .......criterion=absolute_error, min_samples_leaf=4; total time=   0.0s
# [CV] END .......criterion=absolute_error, min_samples_leaf=4; total time=   0.0s
# GridSearchCV(cv=KFold(n_splits=10, random_state=None, shuffle=False),
#              estimator=DecisionTreeRegressor(random_state=2022), n_jobs=1,
#              param_grid={'criterion': ['squared_error', 'friedman_mse',
#                                        'absolute_error'],
#                          'min_samples_leaf': range(1, 5)},
#              return_train_score=True, scoring='neg_mean_absolute_error',
#              verbose=2)

# %%
print(f'The best parameters are: {grid.best_params_}')
print(f'The best score that we got is: {grid.best_score_}')
# Out:
# The best parameters are: {'criterion': 'absolute_error', 'min_samples_leaf': 4}
# The best score that we got is: -141.50906084656086

# %%
predictions = grid.predict(X_test)
predictions
# Out:
# array([2016. , 1829. , 2019. , 1927. , 1955. , 2106. , 1943. , 1930. ,
#        2088.5, 1853. , 1927. , 1734. , 1914. , 1841. , 2216. , 2106. ,
#        1976. , 1963. , 1759. , 1818.5, 1759. , 1811.5, 2216. , 2016. ,
#        1917. , 2106. , 1943. , 1734. , 1930. , 1738.5, 1896. , 1914. ,
#        1930. , 1879.5, 2114. , 1893. , 1981.5, 1930. , 2016. , 1776. ,
#        1918. , 1876. , 1818.5, 1811.5, 1917. , 1887.5, 1879.5, 1876. ,
#        1879. , 1738.5, 1847. , 1927. , 1841. , 1879. , 1927.5, 2228. ,
#        2106. , 1861. , 1833. , 1927. , 1936. , 1865. , 1917. , 1930. ,
#        1887.5, 1826.5, 1865. , 2228. , 1955. , 2196. , 1876. , 1833. ,
#        2019. , 1930. , 1801.5, 1881.5, 1896. , 1955. , 1881.5, 1896. ,
#        1927.5, 2228. , 1914. , 1876. , 1917. , 1847. , 1981.5, 1865. ,
#        1927.5, 1865. , 1818.5])

# %% [markdown]
# #### Avaliação

# %%
plt.scatter(y_test, predictions)

# %%
plt.hist(y_test - predictions.reshape(91,1))
# Out:
# (array([ 1.,  0.,  0.,  3.,  3., 30., 38.,  6.,  6.,  4.]),
#  array([-962. , -804.9, -647.8, -490.7, -333.6, -176.5,  -19.4,  137.7,
#          294.8,  451.9,  609. ]),
#  <BarContainer object of 10 artists>)

# %%
print('MAE:', metrics.mean_absolute_error(y_test, predictions))
print('MSE:', metrics.mean_squared_error(y_test, predictions))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, predictions)))
# Out:
# MAE: 129.7967032967033
# MSE: 43566.36538461538
# RMSE: 208.7255743425213

# %% [markdown]
# ### SVM - Support Vector Machine

# %% [markdown]
# #### Treino e Previsão

# %%
from sklearn.svm import SVR

# %%
params = {'C':[1,10,100,1000], 'gamma':[1,0.1,0.001,0.0001], 'kernel':['linear','rbf']}
clf = SVR()

# %%
grid = GridSearchCV(clf, params, cv=KFold(n_splits=3), n_jobs=1, verbose=2, return_train_score=True, scoring='neg_mean_absolute_error', refit=True)

# %%
grid.fit(X_train,y_train.values.ravel())
# Out:
# Fitting 3 folds for each of 32 candidates, totalling 96 fits
# [CV] END ........................C=1, gamma=1, kernel=linear; total time=   7.5s
# [CV] END ........................C=1, gamma=1, kernel=linear; total time=  18.7s
# [CV] END ........................C=1, gamma=1, kernel=linear; total time=  18.8s
# [CV] END ...........................C=1, gamma=1, kernel=rbf; total time=   0.0s
# [CV] END ...........................C=1, gamma=1, kernel=rbf; total time=   0.0s
# [CV] END ...........................C=1, gamma=1, kernel=rbf; total time=   0.0s
# [CV] END ......................C=1, gamma=0.1, kernel=linear; total time=   7.4s
# [CV] END ......................C=1, gamma=0.1, kernel=linear; total time=  18.9s
# [CV] END ......................C=1, gamma=0.1, kernel=linear; total time=  18.9s
# [CV] END .........................C=1, gamma=0.1, kernel=rbf; total time=   0.0s
# [CV] END .........................C=1, gamma=0.1, kernel=rbf; total time=   0.0s
# [CV] END .........................C=1, gamma=0.1, kernel=rbf; total time=   0.0s
# [CV] END ....................C=1, gamma=0.001, kernel=linear; total time=   7.4s
# [CV] END ....................C=1, gamma=0.001, kernel=linear; total time=  18.7s
# [CV] END ....................C=1, gamma=0.001, kernel=linear; total time=  18.9s
# [CV] END .......................C=1, gamma=0.001, kernel=rbf; total time=   0.0s
# [CV] END .......................C=1, gamma=0.001, kernel=rbf; total time=   0.0s
# [CV] END .......................C=1, gamma=0.001, kernel=rbf; total time=   0.0s
# [CV] END ...................C=1, gamma=0.0001, kernel=linear; total time=   7.4s
# [CV] END ...................C=1, gamma=0.0001, kernel=linear; total time=  18.6s
# [CV] END ...................C=1, gamma=0.0001, kernel=linear; total time=  18.8s
# [CV] END ......................C=1, gamma=0.0001, kernel=rbf; total time=   0.0s
# [CV] END ......................C=1, gamma=0.0001, kernel=rbf; total time=   0.0s
# [CV] END ......................C=1, gamma=0.0001, kernel=rbf; total time=   0.0s
# [CV] END .......................C=10, gamma=1, kernel=linear; total time= 1.5min
# [CV] END .......................C=10, gamma=1, kernel=linear; total time=  49.5s
# [CV] END .......................C=10, gamma=1, kernel=linear; total time=  28.8s
# [CV] END ..........................C=10, gamma=1, kernel=rbf; total time=   0.0s
# [CV] END ..........................C=10, gamma=1, kernel=rbf; total time=   0.0s
# [CV] END ..........................C=10, gamma=1, kernel=rbf; total time=   0.0s
# [CV] END .....................C=10, gamma=0.1, kernel=linear; total time= 1.5min
# [CV] END .....................C=10, gamma=0.1, kernel=linear; total time=  48.2s
# [CV] END .....................C=10, gamma=0.1, kernel=linear; total time=  27.9s
# [CV] END ........................C=10, gamma=0.1, kernel=rbf; total time=   0.0s
# [CV] END ........................C=10, gamma=0.1, kernel=rbf; total time=   0.0s
# [CV] END ........................C=10, gamma=0.1, kernel=rbf; total time=   0.0s
# [CV] END ...................C=10, gamma=0.001, kernel=linear; total time= 1.5min
# [CV] END ...................C=10, gamma=0.001, kernel=linear; total time=  48.6s
# [CV] END ...................C=10, gamma=0.001, kernel=linear; total time=  28.6s
# [CV] END ......................C=10, gamma=0.001, kernel=rbf; total time=   0.0s
# [CV] END ......................C=10, gamma=0.001, kernel=rbf; total time=   0.0s
# [CV] END ......................C=10, gamma=0.001, kernel=rbf; total time=   0.0s
# [CV] END ..................C=10, gamma=0.0001, kernel=linear; total time= 1.5min
# [CV] END ..................C=10, gamma=0.0001, kernel=linear; total time=  48.1s
# [CV] END ..................C=10, gamma=0.0001, kernel=linear; total time=  27.8s
# [CV] END .....................C=10, gamma=0.0001, kernel=rbf; total time=   0.0s
# [CV] END .....................C=10, gamma=0.0001, kernel=rbf; total time=   0.0s
# [CV] END .....................C=10, gamma=0.0001, kernel=rbf; total time=   0.0s
# [CV] END ......................C=100, gamma=1, kernel=linear; total time= 1.9min
# [CV] END ......................C=100, gamma=1, kernel=linear; total time= 3.5min
# [CV] END ......................C=100, gamma=1, kernel=linear; total time= 1.3min
# [CV] END .........................C=100, gamma=1, kernel=rbf; total time=   0.0s
# [CV] END .........................C=100, gamma=1, kernel=rbf; total time=   0.0s
# [CV] END .........................C=100, gamma=1, kernel=rbf; total time=   0.0s
# [CV] END ....................C=100, gamma=0.1, kernel=linear; total time= 1.9min
# [CV] END ....................C=100, gamma=0.1, kernel=linear; total time= 3.6min
# [CV] END ....................C=100, gamma=0.1, kernel=linear; total time= 1.3min
# [CV] END .......................C=100, gamma=0.1, kernel=rbf; total time=   0.0s
# [CV] END .......................C=100, gamma=0.1, kernel=rbf; total time=   0.0s
# [CV] END .......................C=100, gamma=0.1, kernel=rbf; total time=   0.0s
# [CV] END ..................C=100, gamma=0.001, kernel=linear; total time= 1.9min
# [CV] END ..................C=100, gamma=0.001, kernel=linear; total time= 3.5min
# [CV] END ..................C=100, gamma=0.001, kernel=linear; total time= 1.3min
# [CV] END .....................C=100, gamma=0.001, kernel=rbf; total time=   0.0s
# [CV] END .....................C=100, gamma=0.001, kernel=rbf; total time=   0.0s
# [CV] END .....................C=100, gamma=0.001, kernel=rbf; total time=   0.0s
# [CV] END .................C=100, gamma=0.0001, kernel=linear; total time= 1.9min
# [CV] END .................C=100, gamma=0.0001, kernel=linear; total time= 3.5min
# [CV] END .................C=100, gamma=0.0001, kernel=linear; total time= 1.3min
# [CV] END ....................C=100, gamma=0.0001, kernel=rbf; total time=   0.0s
# [CV] END ....................C=100, gamma=0.0001, kernel=rbf; total time=   0.0s
# [CV] END ....................C=100, gamma=0.0001, kernel=rbf; total time=   0.0s
# [CV] END .....................C=1000, gamma=1, kernel=linear; total time=  41.2s
# [CV] END .....................C=1000, gamma=1, kernel=linear; total time= 1.1min
# [CV] END .....................C=1000, gamma=1, kernel=linear; total time= 1.4min
# [CV] END ........................C=1000, gamma=1, kernel=rbf; total time=   0.0s
# [CV] END ........................C=1000, gamma=1, kernel=rbf; total time=   0.0s
# [CV] END ........................C=1000, gamma=1, kernel=rbf; total time=   0.0s
# [CV] END ...................C=1000, gamma=0.1, kernel=linear; total time=  40.6s
# [CV] END ...................C=1000, gamma=0.1, kernel=linear; total time= 1.1min
# [CV] END ...................C=1000, gamma=0.1, kernel=linear; total time= 1.4min
# [CV] END ......................C=1000, gamma=0.1, kernel=rbf; total time=   0.0s
# [CV] END ......................C=1000, gamma=0.1, kernel=rbf; total time=   0.0s
# [CV] END ......................C=1000, gamma=0.1, kernel=rbf; total time=   0.0s
# [CV] END .................C=1000, gamma=0.001, kernel=linear; total time=  40.5s
# [CV] END .................C=1000, gamma=0.001, kernel=linear; total time= 1.1min
# [CV] END .................C=1000, gamma=0.001, kernel=linear; total time= 1.5min
# [CV] END ....................C=1000, gamma=0.001, kernel=rbf; total time=   0.0s
# [CV] END ....................C=1000, gamma=0.001, kernel=rbf; total time=   0.0s
# [CV] END ....................C=1000, gamma=0.001, kernel=rbf; total time=   0.0s
# [CV] END ................C=1000, gamma=0.0001, kernel=linear; total time=  40.7s
# [CV] END ................C=1000, gamma=0.0001, kernel=linear; total time= 1.1min
# [CV] END ................C=1000, gamma=0.0001, kernel=linear; total time= 1.4min
# [CV] END ...................C=1000, gamma=0.0001, kernel=rbf; total time=   0.0s
# [CV] END ...................C=1000, gamma=0.0001, kernel=rbf; total time=   0.0s
# [CV] END ...................C=1000, gamma=0.0001, kernel=rbf; total time=   0.0s
# GridSearchCV(cv=KFold(n_splits=3, random_state=None, shuffle=False),
#              estimator=SVR(), n_jobs=1,
#              param_grid={'C': [1, 10, 100, 1000],
#                          'gamma': [1, 0.1, 0.001, 0.0001],
#                          'kernel': ['linear', 'rbf']},
#              return_train_score=True, scoring='neg_mean_absolute_error',
#              verbose=2)

# %%
print(f'The best parameters are: {grid.best_params_}')
print(f'The best score that we got is: {grid.best_score_}')
# Out:
# The best parameters are: {'C': 1, 'gamma': 1, 'kernel': 'linear'}
# The best score that we got is: -116.83062203029124

# %%
predictions = grid.predict(X_test)
predictions
# Out:
# array([1980.94803536, 1857.96764082, 1892.77944791, 1965.69656336,
#        1976.54638708, 2094.70824301, 1966.69812524, 1950.75431907,
#        1875.57945329, 1886.41558525, 1943.34082174, 1846.48611984,
#        1946.76337659, 1872.79032785, 1995.43526995, 2027.01555908,
#        2013.15473998, 1892.51676148, 1806.55167577, 1831.45087728,
#        1825.79382768, 1837.68377382, 2010.19467521, 2018.61703563,
#        1849.71823108, 2067.77941358, 1965.29959667, 1849.75104961,
#        1947.51408517, 1914.11619449, 1881.61515594, 1941.50544632,
#        1945.84396136, 1885.91370797, 1948.2484901 , 1907.79671681,
#        1964.45330966, 1902.31059164, 2019.28794181, 1791.2375868 ,
#        1918.56765759, 1865.90805429, 1814.56372877, 1858.05718112,
#        1872.19961307, 1841.90707284, 1872.17186248, 1869.72056323,
#        1880.11197507, 1929.90569598, 1833.51075272, 1957.51113308,
#        1896.44615865, 1929.31246126, 1891.92414948, 1871.93509537,
#        2054.42123163, 1856.27399623, 1804.1892795 , 1970.99841786,
#        1927.51477772, 1841.49669081, 1864.93219531, 1900.79656136,
#        1829.03919467, 1812.67365679, 1836.78928226, 1900.14338827,
#        2040.23440611, 1898.75572866, 1881.67254803, 1813.32137281,
#        1905.01362133, 1932.90871728, 1848.55474573, 1820.80871049,
#        1899.96628881, 2019.13525748, 1817.44526145, 1895.77179629,
#        1924.69144675, 1922.46741146, 1949.15776157, 1844.12920588,
#        1858.96538103, 1846.43598676, 1964.95522058, 1840.40870613,
#        1888.92914071, 1830.29935785, 1796.85552411])

# %% [markdown]
# #### Avaliação

# %%
plt.scatter(y_test, predictions)

# %%
plt.hist(y_test - predictions.reshape(91,1))
# Out:
# (array([ 1.,  0.,  0.,  1.,  1., 49., 21., 12.,  5.,  1.]),
#  array([-933.78928226, -774.30357357, -614.81786487, -455.33215618,
#         -295.84644748, -136.36073879,   23.12496991,  182.61067861,
#          342.0963873 ,  501.582096  ,  661.06780469]),
#  <BarContainer object of 10 artists>)

# %%
print('MAE:', metrics.mean_absolute_error(y_test, predictions))
print('MSE:', metrics.mean_squared_error(y_test, predictions))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, predictions)))
# Out:
# MAE: 116.38253541332804
# MSE: 37537.84851375054
# RMSE: 193.74686710693038

# %% [markdown]
# ### Florestas Aleatórias (Random Forests)

# %% [markdown]
# #### Treino e Previsão

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
params = {
    'bootstrap': [True],
    'max_depth': [80, 90, 100, 110],
    'max_features': [2, 3],
    'min_samples_leaf': [3, 4, 5],
    'min_samples_split': [8, 10, 12],
    'n_estimators': [100, 200, 300, 1000]
}
clf = RandomForestRegressor(random_state=2022)

# %%
grid = GridSearchCV(clf, params, cv=KFold(n_splits=10), n_jobs=1, verbose=2, return_train_score=True, scoring='neg_mean_absolute_error', refit=True)

# %%
grid.fit(X_train,y_train.values.ravel())
# Out:
# Fitting 10 folds for each of 288 candidates, totalling 2880 fits
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=3, min_samples_split=8, n_estimators=100; total time=   0.0s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=3, min_samples_split=8, n_estimators=100; total time=   0.0s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=3, min_samples_split=8, n_estimators=100; total time=   0.0s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=3, min_samples_split=8, n_estimators=100; total time=   0.0s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=3, min_samples_split=8, n_estimators=100; total time=   0.0s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=3, min_samples_split=8, n_estimators=100; total time=   0.0s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=3, min_samples_split=8, n_estimators=100; total time=   0.0s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=3, min_samples_split=8, n_estimators=100; total time=   0.0s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=3, min_samples_split=8, n_estimators=100; total time=   0.0s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=3, min_samples_split=8, n_estimators=100; total time=   0.0s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=3, min_samples_split=8, n_estimators=200; total time=   0.1s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=3, min_samples_split=8, n_estimators=200; total time=   0.1s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=3, min_samples_split=8, n_estimators=200; total time=   0.2s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=3, min_samples_split=8, n_estimators=200; total time=   0.1s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=3, min_samples_split=8, n_estimators=200; total time=   0.1s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=3, min_samples_split=8, n_estimators=200; total time=   0.1s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=3, min_samples_split=8, n_estimators=200; total time=   0.1s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=3, min_samples_split=8, n_estimators=200; total time=   0.1s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=3, min_samples_split=8, n_estimators=200; total time=   0.1s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=3, min_samples_split=8, n_estimators=200; total time=   0.1s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=3, min_samples_split=8, n_estimators=300; total time=   0.2s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=3, min_samples_split=8, n_estimators=300; total time=   0.2s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=3, min_samples_split=8, n_estimators=300; total time=   0.2s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=3, min_samples_split=8, n_estimators=300; total time=   0.2s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=3, min_samples_split=8, n_estimators=300; total time=   0.2s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=3, min_samples_split=8, n_estimators=300; total time=   0.2s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=3, min_samples_split=8, n_estimators=300; total time=   0.2s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=3, min_samples_split=8, n_estimators=300; total time=   0.2s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=3, min_samples_split=8, n_estimators=300; total time=   0.2s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=3, min_samples_split=8, n_estimators=300; total time=   0.2s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=3, min_samples_split=8, n_estimators=1000; total time=   0.9s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=3, min_samples_split=8, n_estimators=1000; total time=   0.9s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=3, min_samples_split=8, n_estimators=1000; total time=   0.9s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=3, min_samples_split=8, n_estimators=1000; total time=   1.0s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=3, min_samples_split=8, n_estimators=1000; total time=   0.9s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=3, min_samples_split=8, n_estimators=1000; total time=   0.9s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=3, min_samples_split=8, n_estimators=1000; total time=   0.9s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=3, min_samples_split=8, n_estimators=1000; total time=   0.9s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=3, min_samples_split=8, n_estimators=1000; total time=   0.9s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=3, min_samples_split=8, n_estimators=1000; total time=   0.9s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=3, min_samples_split=10, n_estimators=100; total time=   0.0s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=3, min_samples_split=10, n_estimators=100; total time=   0.0s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=3, min_samples_split=10, n_estimators=100; total time=   0.0s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=3, min_samples_split=10, n_estimators=100; total time=   0.0s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=3, min_samples_split=10, n_estimators=100; total time=   0.0s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=3, min_samples_split=10, n_estimators=100; total time=   0.0s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=3, min_samples_split=10, n_estimators=100; total time=   0.0s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=3, min_samples_split=10, n_estimators=100; total time=   0.0s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=3, min_samples_split=10, n_estimators=100; total time=   0.0s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=3, min_samples_split=10, n_estimators=100; total time=   0.0s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=3, min_samples_split=10, n_estimators=200; total time=   0.1s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=3, min_samples_split=10, n_estimators=200; total time=   0.1s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=3, min_samples_split=10, n_estimators=200; total time=   0.1s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=3, min_samples_split=10, n_estimators=200; total time=   0.1s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=3, min_samples_split=10, n_estimators=200; total time=   0.1s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=3, min_samples_split=10, n_estimators=200; total time=   0.1s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=3, min_samples_split=10, n_estimators=200; total time=   0.1s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=3, min_samples_split=10, n_estimators=200; total time=   0.1s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=3, min_samples_split=10, n_estimators=200; total time=   0.1s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=3, min_samples_split=10, n_estimators=200; total time=   0.1s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=3, min_samples_split=10, n_estimators=300; total time=   0.2s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=3, min_samples_split=10, n_estimators=300; total time=   0.2s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=3, min_samples_split=10, n_estimators=300; total time=   0.2s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=3, min_samples_split=10, n_estimators=300; total time=   0.2s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=3, min_samples_split=10, n_estimators=300; total time=   0.2s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=3, min_samples_split=10, n_estimators=300; total time=   0.2s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=3, min_samples_split=10, n_estimators=300; total time=   0.2s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=3, min_samples_split=10, n_estimators=300; total time=   0.2s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=3, min_samples_split=10, n_estimators=300; total time=   0.2s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=3, min_samples_split=10, n_estimators=300; total time=   0.2s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=3, min_samples_split=10, n_estimators=1000; total time=   1.5s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=3, min_samples_split=10, n_estimators=1000; total time=   1.3s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=3, min_samples_split=10, n_estimators=1000; total time=   1.1s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=3, min_samples_split=10, n_estimators=1000; total time=   1.0s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=3, min_samples_split=10, n_estimators=1000; total time=   1.1s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=3, min_samples_split=10, n_estimators=1000; total time=   1.0s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=3, min_samples_split=10, n_estimators=1000; total time=   0.9s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=3, min_samples_split=10, n_estimators=1000; total time=   0.9s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=3, min_samples_split=10, n_estimators=1000; total time=   0.9s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=3, min_samples_split=10, n_estimators=1000; total time=   0.9s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=3, min_samples_split=12, n_estimators=100; total time=   0.0s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=3, min_samples_split=12, n_estimators=100; total time=   0.0s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=3, min_samples_split=12, n_estimators=100; total time=   0.0s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=3, min_samples_split=12, n_estimators=100; total time=   0.0s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=3, min_samples_split=12, n_estimators=100; total time=   0.0s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=3, min_samples_split=12, n_estimators=100; total time=   0.0s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=3, min_samples_split=12, n_estimators=100; total time=   0.0s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=3, min_samples_split=12, n_estimators=100; total time=   0.0s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=3, min_samples_split=12, n_estimators=100; total time=   0.0s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=3, min_samples_split=12, n_estimators=100; total time=   0.0s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=3, min_samples_split=12, n_estimators=200; total time=   0.1s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=3, min_samples_split=12, n_estimators=200; total time=   0.1s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=3, min_samples_split=12, n_estimators=200; total time=   0.1s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=3, min_samples_split=12, n_estimators=200; total time=   0.1s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=3, min_samples_split=12, n_estimators=200; total time=   0.1s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=3, min_samples_split=12, n_estimators=200; total time=   0.1s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=3, min_samples_split=12, n_estimators=200; total time=   0.1s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=3, min_samples_split=12, n_estimators=200; total time=   0.1s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=3, min_samples_split=12, n_estimators=200; total time=   0.1s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=3, min_samples_split=12, n_estimators=200; total time=   0.1s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=3, min_samples_split=12, n_estimators=300; total time=   0.2s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=3, min_samples_split=12, n_estimators=300; total time=   0.2s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=3, min_samples_split=12, n_estimators=300; total time=   0.2s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=3, min_samples_split=12, n_estimators=300; total time=   0.2s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=3, min_samples_split=12, n_estimators=300; total time=   0.2s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=3, min_samples_split=12, n_estimators=300; total time=   0.2s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=3, min_samples_split=12, n_estimators=300; total time=   0.2s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=3, min_samples_split=12, n_estimators=300; total time=   0.2s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=3, min_samples_split=12, n_estimators=300; total time=   0.2s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=3, min_samples_split=12, n_estimators=300; total time=   0.2s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=3, min_samples_split=12, n_estimators=1000; total time=   1.0s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=3, min_samples_split=12, n_estimators=1000; total time=   0.9s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=3, min_samples_split=12, n_estimators=1000; total time=   1.0s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=3, min_samples_split=12, n_estimators=1000; total time=   0.9s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=3, min_samples_split=12, n_estimators=1000; total time=   1.0s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=3, min_samples_split=12, n_estimators=1000; total time=   1.0s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=3, min_samples_split=12, n_estimators=1000; total time=   1.1s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=3, min_samples_split=12, n_estimators=1000; total time=   0.9s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=3, min_samples_split=12, n_estimators=1000; total time=   0.9s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=3, min_samples_split=12, n_estimators=1000; total time=   0.9s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=4, min_samples_split=8, n_estimators=100; total time=   0.0s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=4, min_samples_split=8, n_estimators=100; total time=   0.0s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=4, min_samples_split=8, n_estimators=100; total time=   0.0s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=4, min_samples_split=8, n_estimators=100; total time=   0.0s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=4, min_samples_split=8, n_estimators=100; total time=   0.0s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=4, min_samples_split=8, n_estimators=100; total time=   0.0s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=4, min_samples_split=8, n_estimators=100; total time=   0.0s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=4, min_samples_split=8, n_estimators=100; total time=   0.0s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=4, min_samples_split=8, n_estimators=100; total time=   0.0s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=4, min_samples_split=8, n_estimators=100; total time=   0.0s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=4, min_samples_split=8, n_estimators=200; total time=   0.1s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=4, min_samples_split=8, n_estimators=200; total time=   0.1s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=4, min_samples_split=8, n_estimators=200; total time=   0.1s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=4, min_samples_split=8, n_estimators=200; total time=   0.1s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=4, min_samples_split=8, n_estimators=200; total time=   0.1s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=4, min_samples_split=8, n_estimators=200; total time=   0.1s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=4, min_samples_split=8, n_estimators=200; total time=   0.1s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=4, min_samples_split=8, n_estimators=200; total time=   0.1s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=4, min_samples_split=8, n_estimators=200; total time=   0.1s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=4, min_samples_split=8, n_estimators=200; total time=   0.1s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=4, min_samples_split=8, n_estimators=300; total time=   0.2s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=4, min_samples_split=8, n_estimators=300; total time=   0.2s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=4, min_samples_split=8, n_estimators=300; total time=   0.2s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=4, min_samples_split=8, n_estimators=300; total time=   0.2s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=4, min_samples_split=8, n_estimators=300; total time=   0.2s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=4, min_samples_split=8, n_estimators=300; total time=   0.2s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=4, min_samples_split=8, n_estimators=300; total time=   0.2s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=4, min_samples_split=8, n_estimators=300; total time=   0.2s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=4, min_samples_split=8, n_estimators=300; total time=   0.2s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=4, min_samples_split=8, n_estimators=300; total time=   0.2s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=4, min_samples_split=8, n_estimators=1000; total time=   0.9s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=4, min_samples_split=8, n_estimators=1000; total time=   0.9s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=4, min_samples_split=8, n_estimators=1000; total time=   0.9s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=4, min_samples_split=8, n_estimators=1000; total time=   1.0s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=4, min_samples_split=8, n_estimators=1000; total time=   0.9s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=4, min_samples_split=8, n_estimators=1000; total time=   0.9s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=4, min_samples_split=8, n_estimators=1000; total time=   0.9s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=4, min_samples_split=8, n_estimators=1000; total time=   0.9s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=4, min_samples_split=8, n_estimators=1000; total time=   0.9s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=4, min_samples_split=8, n_estimators=1000; total time=   0.9s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=   0.0s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=   0.0s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=   0.0s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=   0.0s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=   0.0s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=   0.0s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=   0.0s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=   0.0s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=   0.0s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=   0.0s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=   0.1s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=   0.1s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=   0.1s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=   0.1s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=   0.1s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=   0.2s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=   0.1s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=   0.1s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=   0.1s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=   0.1s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=4, min_samples_split=10, n_estimators=300; total time=   0.2s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=4, min_samples_split=10, n_estimators=300; total time=   0.2s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=4, min_samples_split=10, n_estimators=300; total time=   0.2s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=4, min_samples_split=10, n_estimators=300; total time=   0.2s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=4, min_samples_split=10, n_estimators=300; total time=   0.2s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=4, min_samples_split=10, n_estimators=300; total time=   0.2s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=4, min_samples_split=10, n_estimators=300; total time=   0.2s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=4, min_samples_split=10, n_estimators=300; total time=   0.2s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=4, min_samples_split=10, n_estimators=300; total time=   0.2s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=4, min_samples_split=10, n_estimators=300; total time=   0.2s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=4, min_samples_split=10, n_estimators=1000; total time=   1.0s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=4, min_samples_split=10, n_estimators=1000; total time=   0.9s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=4, min_samples_split=10, n_estimators=1000; total time=   0.9s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=4, min_samples_split=10, n_estimators=1000; total time=   1.0s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=4, min_samples_split=10, n_estimators=1000; total time=   0.9s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=4, min_samples_split=10, n_estimators=1000; total time=   1.1s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=4, min_samples_split=10, n_estimators=1000; total time=   1.1s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=4, min_samples_split=10, n_estimators=1000; total time=   1.2s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=4, min_samples_split=10, n_estimators=1000; total time=   1.0s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=4, min_samples_split=10, n_estimators=1000; total time=   1.0s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=4, min_samples_split=12, n_estimators=100; total time=   0.0s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=4, min_samples_split=12, n_estimators=100; total time=   0.0s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=4, min_samples_split=12, n_estimators=100; total time=   0.0s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=4, min_samples_split=12, n_estimators=100; total time=   0.0s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=4, min_samples_split=12, n_estimators=100; total time=   0.0s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=4, min_samples_split=12, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=4, min_samples_split=12, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=4, min_samples_split=12, n_estimators=100; total time=   0.0s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=4, min_samples_split=12, n_estimators=100; total time=   0.0s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=4, min_samples_split=12, n_estimators=100; total time=   0.0s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=4, min_samples_split=12, n_estimators=200; total time=   0.1s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=4, min_samples_split=12, n_estimators=200; total time=   0.1s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=4, min_samples_split=12, n_estimators=200; total time=   0.1s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=4, min_samples_split=12, n_estimators=200; total time=   0.1s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=4, min_samples_split=12, n_estimators=200; total time=   0.1s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=4, min_samples_split=12, n_estimators=200; total time=   0.1s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=4, min_samples_split=12, n_estimators=200; total time=   0.1s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=4, min_samples_split=12, n_estimators=200; total time=   0.1s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=4, min_samples_split=12, n_estimators=200; total time=   0.1s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=4, min_samples_split=12, n_estimators=200; total time=   0.1s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=4, min_samples_split=12, n_estimators=300; total time=   0.2s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=4, min_samples_split=12, n_estimators=300; total time=   0.3s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=4, min_samples_split=12, n_estimators=300; total time=   0.2s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=4, min_samples_split=12, n_estimators=300; total time=   0.3s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=4, min_samples_split=12, n_estimators=300; total time=   0.3s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=4, min_samples_split=12, n_estimators=300; total time=   0.3s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=4, min_samples_split=12, n_estimators=300; total time=   0.4s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=4, min_samples_split=12, n_estimators=300; total time=   0.3s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=4, min_samples_split=12, n_estimators=300; total time=   0.3s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=4, min_samples_split=12, n_estimators=300; total time=   0.2s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=4, min_samples_split=12, n_estimators=1000; total time=   1.0s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=4, min_samples_split=12, n_estimators=1000; total time=   1.1s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=4, min_samples_split=12, n_estimators=1000; total time=   1.1s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=4, min_samples_split=12, n_estimators=1000; total time=   1.2s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=4, min_samples_split=12, n_estimators=1000; total time=   0.9s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=4, min_samples_split=12, n_estimators=1000; total time=   0.9s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=4, min_samples_split=12, n_estimators=1000; total time=   1.1s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=4, min_samples_split=12, n_estimators=1000; total time=   1.4s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=4, min_samples_split=12, n_estimators=1000; total time=   1.1s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=4, min_samples_split=12, n_estimators=1000; total time=   0.9s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=5, min_samples_split=8, n_estimators=100; total time=   0.0s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=5, min_samples_split=8, n_estimators=100; total time=   0.0s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=5, min_samples_split=8, n_estimators=100; total time=   0.0s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=5, min_samples_split=8, n_estimators=100; total time=   0.0s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=5, min_samples_split=8, n_estimators=100; total time=   0.0s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=5, min_samples_split=8, n_estimators=100; total time=   0.0s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=5, min_samples_split=8, n_estimators=100; total time=   0.0s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=5, min_samples_split=8, n_estimators=100; total time=   0.0s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=5, min_samples_split=8, n_estimators=100; total time=   0.0s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=5, min_samples_split=8, n_estimators=100; total time=   0.0s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=5, min_samples_split=8, n_estimators=200; total time=   0.1s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=5, min_samples_split=8, n_estimators=200; total time=   0.1s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=5, min_samples_split=8, n_estimators=200; total time=   0.1s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=5, min_samples_split=8, n_estimators=200; total time=   0.1s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=5, min_samples_split=8, n_estimators=200; total time=   0.1s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=5, min_samples_split=8, n_estimators=200; total time=   0.1s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=5, min_samples_split=8, n_estimators=200; total time=   0.1s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=5, min_samples_split=8, n_estimators=200; total time=   0.1s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=5, min_samples_split=8, n_estimators=200; total time=   0.2s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=5, min_samples_split=8, n_estimators=200; total time=   0.1s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=5, min_samples_split=8, n_estimators=300; total time=   0.2s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=5, min_samples_split=8, n_estimators=300; total time=   0.2s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=5, min_samples_split=8, n_estimators=300; total time=   0.2s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=5, min_samples_split=8, n_estimators=300; total time=   0.2s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=5, min_samples_split=8, n_estimators=300; total time=   0.3s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=5, min_samples_split=8, n_estimators=300; total time=   0.2s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=5, min_samples_split=8, n_estimators=300; total time=   0.3s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=5, min_samples_split=8, n_estimators=300; total time=   0.2s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=5, min_samples_split=8, n_estimators=300; total time=   0.2s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=5, min_samples_split=8, n_estimators=300; total time=   0.2s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=5, min_samples_split=8, n_estimators=1000; total time=   0.9s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=5, min_samples_split=8, n_estimators=1000; total time=   1.1s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=5, min_samples_split=8, n_estimators=1000; total time=   1.2s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=5, min_samples_split=8, n_estimators=1000; total time=   1.0s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=5, min_samples_split=8, n_estimators=1000; total time=   1.0s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=5, min_samples_split=8, n_estimators=1000; total time=   1.0s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=5, min_samples_split=8, n_estimators=1000; total time=   1.2s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=5, min_samples_split=8, n_estimators=1000; total time=   1.0s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=5, min_samples_split=8, n_estimators=1000; total time=   1.1s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=5, min_samples_split=8, n_estimators=1000; total time=   1.1s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=5, min_samples_split=10, n_estimators=100; total time=   0.0s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=5, min_samples_split=10, n_estimators=100; total time=   0.0s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=5, min_samples_split=10, n_estimators=100; total time=   0.0s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=5, min_samples_split=10, n_estimators=100; total time=   0.0s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=5, min_samples_split=10, n_estimators=100; total time=   0.0s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=5, min_samples_split=10, n_estimators=100; total time=   0.0s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=5, min_samples_split=10, n_estimators=100; total time=   0.0s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=5, min_samples_split=10, n_estimators=100; total time=   0.0s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=5, min_samples_split=10, n_estimators=100; total time=   0.0s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=5, min_samples_split=10, n_estimators=100; total time=   0.0s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=5, min_samples_split=10, n_estimators=200; total time=   0.1s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=5, min_samples_split=10, n_estimators=200; total time=   0.1s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=5, min_samples_split=10, n_estimators=200; total time=   0.1s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=5, min_samples_split=10, n_estimators=200; total time=   0.1s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=5, min_samples_split=10, n_estimators=200; total time=   0.1s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=5, min_samples_split=10, n_estimators=200; total time=   0.1s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=5, min_samples_split=10, n_estimators=200; total time=   0.1s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=5, min_samples_split=10, n_estimators=200; total time=   0.1s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=5, min_samples_split=10, n_estimators=200; total time=   0.1s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=5, min_samples_split=10, n_estimators=200; total time=   0.1s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=5, min_samples_split=10, n_estimators=300; total time=   0.2s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=5, min_samples_split=10, n_estimators=300; total time=   0.2s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=5, min_samples_split=10, n_estimators=300; total time=   0.2s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=5, min_samples_split=10, n_estimators=300; total time=   0.2s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=5, min_samples_split=10, n_estimators=300; total time=   0.2s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=5, min_samples_split=10, n_estimators=300; total time=   0.2s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=5, min_samples_split=10, n_estimators=300; total time=   0.2s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=5, min_samples_split=10, n_estimators=300; total time=   0.2s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=5, min_samples_split=10, n_estimators=300; total time=   0.2s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=5, min_samples_split=10, n_estimators=300; total time=   0.3s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=5, min_samples_split=10, n_estimators=1000; total time=   1.3s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=5, min_samples_split=10, n_estimators=1000; total time=   0.9s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=5, min_samples_split=10, n_estimators=1000; total time=   1.0s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=5, min_samples_split=10, n_estimators=1000; total time=   1.0s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=5, min_samples_split=10, n_estimators=1000; total time=   0.9s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=5, min_samples_split=10, n_estimators=1000; total time=   0.9s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=5, min_samples_split=10, n_estimators=1000; total time=   0.9s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=5, min_samples_split=10, n_estimators=1000; total time=   0.9s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=5, min_samples_split=10, n_estimators=1000; total time=   0.9s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=5, min_samples_split=10, n_estimators=1000; total time=   0.9s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=5, min_samples_split=12, n_estimators=100; total time=   0.0s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=5, min_samples_split=12, n_estimators=100; total time=   0.0s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=5, min_samples_split=12, n_estimators=100; total time=   0.0s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=5, min_samples_split=12, n_estimators=100; total time=   0.0s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=5, min_samples_split=12, n_estimators=100; total time=   0.0s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=5, min_samples_split=12, n_estimators=100; total time=   0.0s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=5, min_samples_split=12, n_estimators=100; total time=   0.0s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=5, min_samples_split=12, n_estimators=100; total time=   0.0s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=5, min_samples_split=12, n_estimators=100; total time=   0.0s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=5, min_samples_split=12, n_estimators=100; total time=   0.0s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=5, min_samples_split=12, n_estimators=200; total time=   0.1s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=5, min_samples_split=12, n_estimators=200; total time=   0.1s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=5, min_samples_split=12, n_estimators=200; total time=   0.1s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=5, min_samples_split=12, n_estimators=200; total time=   0.1s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=5, min_samples_split=12, n_estimators=200; total time=   0.1s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=5, min_samples_split=12, n_estimators=200; total time=   0.1s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=5, min_samples_split=12, n_estimators=200; total time=   0.1s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=5, min_samples_split=12, n_estimators=200; total time=   0.1s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=5, min_samples_split=12, n_estimators=200; total time=   0.1s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=5, min_samples_split=12, n_estimators=200; total time=   0.1s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=5, min_samples_split=12, n_estimators=300; total time=   0.2s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=5, min_samples_split=12, n_estimators=300; total time=   0.2s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=5, min_samples_split=12, n_estimators=300; total time=   0.2s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=5, min_samples_split=12, n_estimators=300; total time=   0.2s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=5, min_samples_split=12, n_estimators=300; total time=   0.2s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=5, min_samples_split=12, n_estimators=300; total time=   0.2s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=5, min_samples_split=12, n_estimators=300; total time=   0.2s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=5, min_samples_split=12, n_estimators=300; total time=   0.2s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=5, min_samples_split=12, n_estimators=300; total time=   0.2s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=5, min_samples_split=12, n_estimators=300; total time=   0.2s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=5, min_samples_split=12, n_estimators=1000; total time=   0.9s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=5, min_samples_split=12, n_estimators=1000; total time=   0.9s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=5, min_samples_split=12, n_estimators=1000; total time=   0.9s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=5, min_samples_split=12, n_estimators=1000; total time=   0.9s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=5, min_samples_split=12, n_estimators=1000; total time=   0.9s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=5, min_samples_split=12, n_estimators=1000; total time=   0.9s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=5, min_samples_split=12, n_estimators=1000; total time=   0.9s
# ...
# [CV] END bootstrap=True, max_depth=110, max_features=3, min_samples_leaf=5, min_samples_split=8, n_estimators=100; total time=   0.0s
# [CV] END bootstrap=True, max_depth=110, max_features=3, min_samples_leaf=5, min_samples_split=8, n_estimators=100; total time=   0.0s
# [CV] END bootstrap=True, max_depth=110, max_features=3, min_samples_leaf=5, min_samples_split=8, n_estimators=100; total time=   0.0s
# [CV] END bootstrap=True, max_depth=110, max_features=3, min_samples_leaf=5, min_samples_split=8, n_estimators=100; total time=   0.0s
# [CV] END bootstrap=True, max_depth=110, max_features=3, min_samples_leaf=5, min_samples_split=8, n_estimators=200; total time=   0.1s
# [CV] END bootstrap=True, max_depth=110, max_features=3, min_samples_leaf=5, min_samples_split=8, n_estimators=200; total time=   0.1s
# [CV] END bootstrap=True, max_depth=110, max_features=3, min_samples_leaf=5, min_samples_split=8, n_estimators=200; total time=   0.1s
# [CV] END bootstrap=True, max_depth=110, max_features=3, min_samples_leaf=5, min_samples_split=8, n_estimators=200; total time=   0.1s
# [CV] END bootstrap=True, max_depth=110, max_features=3, min_samples_leaf=5, min_samples_split=8, n_estimators=200; total time=   0.1s
# [CV] END bootstrap=True, max_depth=110, max_features=3, min_samples_leaf=5, min_samples_split=8, n_estimators=200; total time=   0.1s
# [CV] END bootstrap=True, max_depth=110, max_features=3, min_samples_leaf=5, min_samples_split=8, n_estimators=200; total time=   0.1s
# [CV] END bootstrap=True, max_depth=110, max_features=3, min_samples_leaf=5, min_samples_split=8, n_estimators=200; total time=   0.1s
# [CV] END bootstrap=True, max_depth=110, max_features=3, min_samples_leaf=5, min_samples_split=8, n_estimators=200; total time=   0.1s
# [CV] END bootstrap=True, max_depth=110, max_features=3, min_samples_leaf=5, min_samples_split=8, n_estimators=200; total time=   0.1s
# [CV] END bootstrap=True, max_depth=110, max_features=3, min_samples_leaf=5, min_samples_split=8, n_estimators=300; total time=   0.2s
# [CV] END bootstrap=True, max_depth=110, max_features=3, min_samples_leaf=5, min_samples_split=8, n_estimators=300; total time=   0.2s
# [CV] END bootstrap=True, max_depth=110, max_features=3, min_samples_leaf=5, min_samples_split=8, n_estimators=300; total time=   0.2s
# [CV] END bootstrap=True, max_depth=110, max_features=3, min_samples_leaf=5, min_samples_split=8, n_estimators=300; total time=   0.2s
# [CV] END bootstrap=True, max_depth=110, max_features=3, min_samples_leaf=5, min_samples_split=8, n_estimators=300; total time=   0.2s
# [CV] END bootstrap=True, max_depth=110, max_features=3, min_samples_leaf=5, min_samples_split=8, n_estimators=300; total time=   0.2s
# [CV] END bootstrap=True, max_depth=110, max_features=3, min_samples_leaf=5, min_samples_split=8, n_estimators=300; total time=   0.2s
# [CV] END bootstrap=True, max_depth=110, max_features=3, min_samples_leaf=5, min_samples_split=8, n_estimators=300; total time=   0.2s
# [CV] END bootstrap=True, max_depth=110, max_features=3, min_samples_leaf=5, min_samples_split=8, n_estimators=300; total time=   0.3s
# [CV] END bootstrap=True, max_depth=110, max_features=3, min_samples_leaf=5, min_samples_split=8, n_estimators=300; total time=   0.2s
# [CV] END bootstrap=True, max_depth=110, max_features=3, min_samples_leaf=5, min_samples_split=8, n_estimators=1000; total time=   1.0s
# [CV] END bootstrap=True, max_depth=110, max_features=3, min_samples_leaf=5, min_samples_split=8, n_estimators=1000; total time=   1.0s
# [CV] END bootstrap=True, max_depth=110, max_features=3, min_samples_leaf=5, min_samples_split=8, n_estimators=1000; total time=   1.1s
# [CV] END bootstrap=True, max_depth=110, max_features=3, min_samples_leaf=5, min_samples_split=8, n_estimators=1000; total time=   1.0s
# [CV] END bootstrap=True, max_depth=110, max_features=3, min_samples_leaf=5, min_samples_split=8, n_estimators=1000; total time=   1.0s
# [CV] END bootstrap=True, max_depth=110, max_features=3, min_samples_leaf=5, min_samples_split=8, n_estimators=1000; total time=   1.0s
# [CV] END bootstrap=True, max_depth=110, max_features=3, min_samples_leaf=5, min_samples_split=8, n_estimators=1000; total time=   0.9s
# [CV] END bootstrap=True, max_depth=110, max_features=3, min_samples_leaf=5, min_samples_split=8, n_estimators=1000; total time=   0.9s
# [CV] END bootstrap=True, max_depth=110, max_features=3, min_samples_leaf=5, min_samples_split=8, n_estimators=1000; total time=   1.0s
# [CV] END bootstrap=True, max_depth=110, max_features=3, min_samples_leaf=5, min_samples_split=8, n_estimators=1000; total time=   1.0s
# [CV] END bootstrap=True, max_depth=110, max_features=3, min_samples_leaf=5, min_samples_split=10, n_estimators=100; total time=   0.0s
# [CV] END bootstrap=True, max_depth=110, max_features=3, min_samples_leaf=5, min_samples_split=10, n_estimators=100; total time=   0.0s
# [CV] END bootstrap=True, max_depth=110, max_features=3, min_samples_leaf=5, min_samples_split=10, n_estimators=100; total time=   0.1s
# [CV] END bootstrap=True, max_depth=110, max_features=3, min_samples_leaf=5, min_samples_split=10, n_estimators=100; total time=   0.0s
# [CV] END bootstrap=True, max_depth=110, max_features=3, min_samples_leaf=5, min_samples_split=10, n_estimators=100; total time=   0.0s
# [CV] END bootstrap=True, max_depth=110, max_features=3, min_samples_leaf=5, min_samples_split=10, n_estimators=100; total time=   0.0s
# [CV] END bootstrap=True, max_depth=110, max_features=3, min_samples_leaf=5, min_samples_split=10, n_estimators=100; total time=   0.0s
# [CV] END bootstrap=True, max_depth=110, max_features=3, min_samples_leaf=5, min_samples_split=10, n_estimators=100; total time=   0.0s
# [CV] END bootstrap=True, max_depth=110, max_features=3, min_samples_leaf=5, min_samples_split=10, n_estimators=100; total time=   0.0s
# [CV] END bootstrap=True, max_depth=110, max_features=3, min_samples_leaf=5, min_samples_split=10, n_estimators=100; total time=   0.0s
# [CV] END bootstrap=True, max_depth=110, max_features=3, min_samples_leaf=5, min_samples_split=10, n_estimators=200; total time=   0.1s
# [CV] END bootstrap=True, max_depth=110, max_features=3, min_samples_leaf=5, min_samples_split=10, n_estimators=200; total time=   0.1s
# [CV] END bootstrap=True, max_depth=110, max_features=3, min_samples_leaf=5, min_samples_split=10, n_estimators=200; total time=   0.1s
# [CV] END bootstrap=True, max_depth=110, max_features=3, min_samples_leaf=5, min_samples_split=10, n_estimators=200; total time=   0.1s
# [CV] END bootstrap=True, max_depth=110, max_features=3, min_samples_leaf=5, min_samples_split=10, n_estimators=200; total time=   0.2s
# [CV] END bootstrap=True, max_depth=110, max_features=3, min_samples_leaf=5, min_samples_split=10, n_estimators=200; total time=   0.1s
# [CV] END bootstrap=True, max_depth=110, max_features=3, min_samples_leaf=5, min_samples_split=10, n_estimators=200; total time=   0.1s
# [CV] END bootstrap=True, max_depth=110, max_features=3, min_samples_leaf=5, min_samples_split=10, n_estimators=200; total time=   0.1s
# [CV] END bootstrap=True, max_depth=110, max_features=3, min_samples_leaf=5, min_samples_split=10, n_estimators=200; total time=   0.1s
# [CV] END bootstrap=True, max_depth=110, max_features=3, min_samples_leaf=5, min_samples_split=10, n_estimators=200; total time=   0.1s
# [CV] END bootstrap=True, max_depth=110, max_features=3, min_samples_leaf=5, min_samples_split=10, n_estimators=300; total time=   0.2s
# [CV] END bootstrap=True, max_depth=110, max_features=3, min_samples_leaf=5, min_samples_split=10, n_estimators=300; total time=   0.2s
# [CV] END bootstrap=True, max_depth=110, max_features=3, min_samples_leaf=5, min_samples_split=10, n_estimators=300; total time=   0.2s
# [CV] END bootstrap=True, max_depth=110, max_features=3, min_samples_leaf=5, min_samples_split=10, n_estimators=300; total time=   0.2s
# [CV] END bootstrap=True, max_depth=110, max_features=3, min_samples_leaf=5, min_samples_split=10, n_estimators=300; total time=   0.2s
# [CV] END bootstrap=True, max_depth=110, max_features=3, min_samples_leaf=5, min_samples_split=10, n_estimators=300; total time=   0.3s
# [CV] END bootstrap=True, max_depth=110, max_features=3, min_samples_leaf=5, min_samples_split=10, n_estimators=300; total time=   0.2s
# [CV] END bootstrap=True, max_depth=110, max_features=3, min_samples_leaf=5, min_samples_split=10, n_estimators=300; total time=   0.2s
# [CV] END bootstrap=True, max_depth=110, max_features=3, min_samples_leaf=5, min_samples_split=10, n_estimators=300; total time=   0.2s
# [CV] END bootstrap=True, max_depth=110, max_features=3, min_samples_leaf=5, min_samples_split=10, n_estimators=300; total time=   0.2s
# [CV] END bootstrap=True, max_depth=110, max_features=3, min_samples_leaf=5, min_samples_split=10, n_estimators=1000; total time=   1.0s
# [CV] END bootstrap=True, max_depth=110, max_features=3, min_samples_leaf=5, min_samples_split=10, n_estimators=1000; total time=   1.0s
# [CV] END bootstrap=True, max_depth=110, max_features=3, min_samples_leaf=5, min_samples_split=10, n_estimators=1000; total time=   1.0s
# [CV] END bootstrap=True, max_depth=110, max_features=3, min_samples_leaf=5, min_samples_split=10, n_estimators=1000; total time=   0.9s
# [CV] END bootstrap=True, max_depth=110, max_features=3, min_samples_leaf=5, min_samples_split=10, n_estimators=1000; total time=   0.9s
# [CV] END bootstrap=True, max_depth=110, max_features=3, min_samples_leaf=5, min_samples_split=10, n_estimators=1000; total time=   0.9s
# [CV] END bootstrap=True, max_depth=110, max_features=3, min_samples_leaf=5, min_samples_split=10, n_estimators=1000; total time=   0.9s
# [CV] END bootstrap=True, max_depth=110, max_features=3, min_samples_leaf=5, min_samples_split=10, n_estimators=1000; total time=   1.0s
# [CV] END bootstrap=True, max_depth=110, max_features=3, min_samples_leaf=5, min_samples_split=10, n_estimators=1000; total time=   1.1s
# [CV] END bootstrap=True, max_depth=110, max_features=3, min_samples_leaf=5, min_samples_split=10, n_estimators=1000; total time=   1.0s
# [CV] END bootstrap=True, max_depth=110, max_features=3, min_samples_leaf=5, min_samples_split=12, n_estimators=100; total time=   0.0s
# [CV] END bootstrap=True, max_depth=110, max_features=3, min_samples_leaf=5, min_samples_split=12, n_estimators=100; total time=   0.0s
# [CV] END bootstrap=True, max_depth=110, max_features=3, min_samples_leaf=5, min_samples_split=12, n_estimators=100; total time=   0.0s
# [CV] END bootstrap=True, max_depth=110, max_features=3, min_samples_leaf=5, min_samples_split=12, n_estimators=100; total time=   0.0s
# [CV] END bootstrap=True, max_depth=110, max_features=3, min_samples_leaf=5, min_samples_split=12, n_estimators=100; total time=   0.0s
# [CV] END bootstrap=True, max_depth=110, max_features=3, min_samples_leaf=5, min_samples_split=12, n_estimators=100; total time=   0.0s
# [CV] END bootstrap=True, max_depth=110, max_features=3, min_samples_leaf=5, min_samples_split=12, n_estimators=100; total time=   0.0s
# [CV] END bootstrap=True, max_depth=110, max_features=3, min_samples_leaf=5, min_samples_split=12, n_estimators=100; total time=   0.0s
# [CV] END bootstrap=True, max_depth=110, max_features=3, min_samples_leaf=5, min_samples_split=12, n_estimators=100; total time=   0.0s
# [CV] END bootstrap=True, max_depth=110, max_features=3, min_samples_leaf=5, min_samples_split=12, n_estimators=100; total time=   0.0s
# [CV] END bootstrap=True, max_depth=110, max_features=3, min_samples_leaf=5, min_samples_split=12, n_estimators=200; total time=   0.1s
# [CV] END bootstrap=True, max_depth=110, max_features=3, min_samples_leaf=5, min_samples_split=12, n_estimators=200; total time=   0.1s
# [CV] END bootstrap=True, max_depth=110, max_features=3, min_samples_leaf=5, min_samples_split=12, n_estimators=200; total time=   0.1s
# [CV] END bootstrap=True, max_depth=110, max_features=3, min_samples_leaf=5, min_samples_split=12, n_estimators=200; total time=   0.1s
# [CV] END bootstrap=True, max_depth=110, max_features=3, min_samples_leaf=5, min_samples_split=12, n_estimators=200; total time=   0.1s
# [CV] END bootstrap=True, max_depth=110, max_features=3, min_samples_leaf=5, min_samples_split=12, n_estimators=200; total time=   0.1s
# [CV] END bootstrap=True, max_depth=110, max_features=3, min_samples_leaf=5, min_samples_split=12, n_estimators=200; total time=   0.1s
# [CV] END bootstrap=True, max_depth=110, max_features=3, min_samples_leaf=5, min_samples_split=12, n_estimators=200; total time=   0.1s
# [CV] END bootstrap=True, max_depth=110, max_features=3, min_samples_leaf=5, min_samples_split=12, n_estimators=200; total time=   0.1s
# [CV] END bootstrap=True, max_depth=110, max_features=3, min_samples_leaf=5, min_samples_split=12, n_estimators=200; total time=   0.1s
# [CV] END bootstrap=True, max_depth=110, max_features=3, min_samples_leaf=5, min_samples_split=12, n_estimators=300; total time=   0.2s
# [CV] END bootstrap=True, max_depth=110, max_features=3, min_samples_leaf=5, min_samples_split=12, n_estimators=300; total time=   0.2s
# [CV] END bootstrap=True, max_depth=110, max_features=3, min_samples_leaf=5, min_samples_split=12, n_estimators=300; total time=   0.2s
# [CV] END bootstrap=True, max_depth=110, max_features=3, min_samples_leaf=5, min_samples_split=12, n_estimators=300; total time=   0.2s
# [CV] END bootstrap=True, max_depth=110, max_features=3, min_samples_leaf=5, min_samples_split=12, n_estimators=300; total time=   0.2s
# [CV] END bootstrap=True, max_depth=110, max_features=3, min_samples_leaf=5, min_samples_split=12, n_estimators=300; total time=   0.2s
# [CV] END bootstrap=True, max_depth=110, max_features=3, min_samples_leaf=5, min_samples_split=12, n_estimators=300; total time=   0.2s
# [CV] END bootstrap=True, max_depth=110, max_features=3, min_samples_leaf=5, min_samples_split=12, n_estimators=300; total time=   0.2s
# [CV] END bootstrap=True, max_depth=110, max_features=3, min_samples_leaf=5, min_samples_split=12, n_estimators=300; total time=   0.2s
# [CV] END bootstrap=True, max_depth=110, max_features=3, min_samples_leaf=5, min_samples_split=12, n_estimators=300; total time=   0.2s
# [CV] END bootstrap=True, max_depth=110, max_features=3, min_samples_leaf=5, min_samples_split=12, n_estimators=1000; total time=   0.9s
# [CV] END bootstrap=True, max_depth=110, max_features=3, min_samples_leaf=5, min_samples_split=12, n_estimators=1000; total time=   1.0s
# [CV] END bootstrap=True, max_depth=110, max_features=3, min_samples_leaf=5, min_samples_split=12, n_estimators=1000; total time=   0.9s
# [CV] END bootstrap=True, max_depth=110, max_features=3, min_samples_leaf=5, min_samples_split=12, n_estimators=1000; total time=   1.0s
# [CV] END bootstrap=True, max_depth=110, max_features=3, min_samples_leaf=5, min_samples_split=12, n_estimators=1000; total time=   0.9s
# [CV] END bootstrap=True, max_depth=110, max_features=3, min_samples_leaf=5, min_samples_split=12, n_estimators=1000; total time=   0.9s
# [CV] END bootstrap=True, max_depth=110, max_features=3, min_samples_leaf=5, min_samples_split=12, n_estimators=1000; total time=   0.9s
# [CV] END bootstrap=True, max_depth=110, max_features=3, min_samples_leaf=5, min_samples_split=12, n_estimators=1000; total time=   0.9s
# [CV] END bootstrap=True, max_depth=110, max_features=3, min_samples_leaf=5, min_samples_split=12, n_estimators=1000; total time=   0.9s
# [CV] END bootstrap=True, max_depth=110, max_features=3, min_samples_leaf=5, min_samples_split=12, n_estimators=1000; total time=   0.9s
# GridSearchCV(cv=KFold(n_splits=10, random_state=None, shuffle=False),
#              estimator=RandomForestRegressor(random_state=2022), n_jobs=1,
#              param_grid={'bootstrap': [True], 'max_depth': [80, 90, 100, 110],
#                          'max_features': [2, 3], 'min_samples_leaf': [3, 4, 5],
#                          'min_samples_split': [8, 10, 12],
#                          'n_estimators': [100, 200, 300, 1000]},
#              return_train_score=True, scoring='neg_mean_absolute_error',
#              verbose=2)

# %%
print(f'The best parameters are: {grid.best_params_}')
print(f'The best score that we got is: {grid.best_score_}')
# Out:
# The best parameters are: {'bootstrap': True, 'max_depth': 80, 'max_features': 2, 'min_samples_leaf': 5, 'min_samples_split': 12, 'n_estimators': 1000}
# The best score that we got is: -122.31774780053597

# %%
predictions = grid.predict(X_test)
predictions
# Out:
# array([1991.08313307, 1874.55540892, 1901.0814373 , 1988.24993427,
#        1955.12834899, 2115.76688229, 1996.04381952, 1940.93054255,
#        1921.79315452, 1887.99802447, 1963.11475137, 1788.24373235,
#        1970.65973336, 1954.75120104, 2062.33885486, 2017.11603833,
#        2005.53547699, 1951.12838067, 1781.26815243, 1764.26564878,
#        1773.02154795, 1854.24354691, 2085.69667256, 1978.86582987,
#        1920.76666202, 2082.24751075, 1994.64731551, 1706.60829427,
#        1943.29913057, 1928.73169006, 1921.773038  , 1953.05742007,
#        1947.31806716, 1957.68453054, 1999.92758542, 1907.4924843 ,
#        1960.04045967, 1907.31804391, 2049.28054525, 1811.37244124,
#        1928.81519124, 1926.53651452, 1729.69908146, 1865.62934948,
#        1885.99658918, 1848.78592138, 1961.873297  , 1889.99174741,
#        1942.17668   , 1969.90686917, 1832.68540868, 1968.33017386,
#        1932.28662705, 2087.47837241, 1877.06765185, 1986.4133456 ,
#        2071.05679726, 1884.1090421 , 1808.30402995, 1976.72703772,
#        1961.68311422, 1845.18130515, 1907.63531859, 1977.94393289,
#        1855.89302339, 1829.8999131 , 1846.24179864, 2037.44971293,
#        2116.99883615, 1941.54312174, 1902.94370795, 1822.09676434,
#        1933.15972265, 1949.39247981, 1831.32786908, 1726.91307728,
#        1952.17223738, 2066.90884987, 1763.0858151 , 1937.05629182,
#        1990.11543497, 2093.44190063, 2004.55252841, 1877.03009907,
#        1880.17238876, 1846.52383503, 1952.90532183, 1835.95456   ,
#        1893.46343026, 1799.47744727, 1732.86577685])

# %% [markdown]
# #### Avaliação

# %%
plt.scatter(y_test, predictions)

# %%
plt.hist(y_test - predictions.reshape(91,1))
# Out:
# (array([ 1.,  0.,  0.,  1.,  2., 40., 31., 10.,  3.,  3.]),
#  array([-943.24179864, -787.08115064, -630.92050263, -474.75985463,
#         -318.59920662, -162.43855862,   -6.27791061,  149.88273739,
#          306.0433854 ,  462.2040334 ,  618.36468141]),
#  <BarContainer object of 10 artists>)

# %%
print('MAE:', metrics.mean_absolute_error(y_test, predictions))
print('MSE:', metrics.mean_squared_error(y_test, predictions))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, predictions)))
# Out:
# MAE: 120.51516222387609
# MSE: 37573.46856971362
# RMSE: 193.83876952176936

# %%
plt.figure(figsize=(20,15))
importance = grid.best_estimator_.feature_importances_
idxs = np.argsort(importance)
plt.title("Feature Importance")
plt.barh(range(len(idxs)),importance[idxs],align="center")
plt.yticks(range(len(idxs)),[X.columns.to_list()[i] for i in idxs])
plt.xlabel("Random Forest Feature Importance")
#plt.tight_layout()
plt.show()

# %% [markdown]
# ### Redes Neuronais Artificiais

# %% [markdown]
# #### Treino e Previsão

# %%
import tensorflow as tf
import tensorflow.keras.layers as L

# %%
def build_model(num_classes, activation='relu', loss='mean_squared_error'):
    model = tf.keras.Sequential()
   
    model.add(L.Dense(32, input_dim=6, activation='relu'))
    
    model.add(L.Dense(64, activation='relu'))
    model.add(L.Dense(64, activation='relu'))
    model.add(L.Dense(128, activation='relu'))
   
    model.add(L.Dropout(0.25))
    model.add(L.Dense(num_classes, activation='relu'))
   
    
    model.compile(
        optimizer='adam',
        loss=loss,
        metrics=['mae']
    )
    
    return model

# %%
model = build_model(1, activation='relu', loss='mean_squared_error')
model.summary()
history = model.fit(
    X_train,
    y_train,
    validation_data=(X_test,y_test),
    batch_size=64,
    epochs=200,
    verbose=1
)
# Out:
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_30 (Dense)            (None, 32)                224
#
#  dense_31 (Dense)            (None, 64)                2112
#
#  dense_32 (Dense)            (None, 64)                4160
#
#  dense_33 (Dense)            (None, 128)               8320
#
#  dropout_6 (Dropout)         (None, 128)               0
#
#  dense_34 (Dense)            (None, 1)                 129
#
# =================================================================
# Total params: 14,945
# Trainable params: 14,945
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/200
# 5/5 [==============================] - 1s 37ms/step - loss: 2035968.5000 - mae: 1337.1266 - val_loss: 1250106.1250 - val_mae: 962.7189
# Epoch 2/200
# 5/5 [==============================] - 0s 7ms/step - loss: 1346819.0000 - mae: 1005.1494 - val_loss: 1310828.3750 - val_mae: 994.2337
# Epoch 3/200
# 5/5 [==============================] - 0s 7ms/step - loss: 1366388.3750 - mae: 1014.5633 - val_loss: 1196969.0000 - val_mae: 952.2450
# Epoch 4/200
# 5/5 [==============================] - 0s 6ms/step - loss: 1291173.0000 - mae: 1004.0657 - val_loss: 1200204.1250 - val_mae: 941.2531
# Epoch 5/200
# 5/5 [==============================] - 0s 5ms/step - loss: 1291664.5000 - mae: 1023.3881 - val_loss: 1187418.1250 - val_mae: 936.0836
# Epoch 6/200
# 5/5 [==============================] - 0s 6ms/step - loss: 1269397.2500 - mae: 994.3697 - val_loss: 1168070.1250 - val_mae: 940.0146
# Epoch 7/200
# 5/5 [==============================] - 0s 7ms/step - loss: 1215847.0000 - mae: 979.9751 - val_loss: 1150546.0000 - val_mae: 929.3638
# Epoch 8/200
# 5/5 [==============================] - 0s 6ms/step - loss: 1118361.0000 - mae: 933.6047 - val_loss: 1136439.8750 - val_mae: 923.1426
# Epoch 9/200
# 5/5 [==============================] - 0s 5ms/step - loss: 1184067.5000 - mae: 974.6521 - val_loss: 1119440.7500 - val_mae: 915.4485
# Epoch 10/200
# 5/5 [==============================] - 0s 5ms/step - loss: 1147903.8750 - mae: 940.5410 - val_loss: 1103924.1250 - val_mae: 912.2913
# Epoch 11/200
# 5/5 [==============================] - 0s 6ms/step - loss: 1136560.5000 - mae: 951.5476 - val_loss: 1081388.6250 - val_mae: 892.8580
# Epoch 12/200
# 5/5 [==============================] - 0s 6ms/step - loss: 1192388.3750 - mae: 965.1616 - val_loss: 1059646.7500 - val_mae: 888.1586
# Epoch 13/200
# 5/5 [==============================] - 0s 6ms/step - loss: 
# Epoch 198/200
# 5/5 [==============================] - 0s 6ms/step - loss: 65704.0625 - mae: 199.1910 - val_loss: 56247.0430 - val_mae: 173.6344
# Epoch 199/200
# 5/5 [==============================] - 0s 6ms/step - loss: 76312.5234 - mae: 209.9058 - val_loss: 45224.3125 - val_mae: 143.8119
# Epoch 200/200
# 5/5 [==============================] - 0s 6ms/step - loss: 72237.2031 - mae: 198.8739 - val_loss: 45348.4062 - val_mae: 143.0162

# %%
predictions = model.predict(X_test)
predictions
# Out:
# array([[2030.3387],
#        [1937.9948],
#        [1823.9731],
#        [2048.6436],
#        [1943.1329],
#        [2164.9263],
#        [2187.6409],
#        [1900.0039],
#        [1718.093 ],
#        [1946.0251],
#        [1971.4615],
#        [1865.566 ],
#        [2070.2307],
#        [1818.1146],
#        [2154.0554],
#        [2067.3079],
#        [2089.8325],
#        [2000.2498],
#        [1734.4861],
#        [1810.316 ],
#        [1844.4835],
#        [1729.9962],
#        [2469.6672],
#        [2091.9622],
#        [2105.0781],
#        [2190.1633],
#        [1994.0142],
#        [1675.7802],
#        [2013.3992],
#        [1958.0942],
#        [1888.5969],
#        [1909.839 ],
#        [1944.6748],
#        [1826.4109],
#        [1946.4077],
#        [1845.7177],
#        [2064.1687],
#        [1846.591 ],
#        [2343.1018],
#        [1744.3585],
#        [1967.3384],
#        [1852.3076],
#        [1739.9957],
#        [1897.3899],
#        [1913.2626],
#        [1817.4932],
#        [1711.2333],
#        [1917.4436],
#        [1912.4541],
#        [2132.0964],
#        [1765.5475],
#        [1897.9528],
#        [1861.3574],
#        [2051.6113],
#        [1803.5093],
#        [2038.6069],
#        [2363.973 ],
#        [1892.6345],
#        [1700.0823],
#        [1987.5219],
#        [2023.9233],
#        [1803.5736],
#        [2116.2832],
#        [1990.2255],
#        [1770.6748],
#        [1732.9158],
#        [1815.9355],
#        [1921.2017],
#        [2101.6882],
#        [1983.966 ],
#        [1894.1835],
#        [1811.7417],
#        [1937.1501],
#        [1817.3572],
#        [1899.3696],
#        [1761.624 ],
#        [1915.9624],
#        [2183.0833],
#        [1811.6589],
#        [1903.7515],
#        [2167.2063],
#        [2534.2068],
#        [1869.4553],
#        [1774.242 ],
#        [1951.9937],
#        [1907.3683],
#        [2017.2688],
#        [1833.7079],
#        [1664.9065],
#        [1753.1709],
#        [1649.9454]], dtype=float32)

# %% [markdown]
# #### Avaliação

# %%
plt.scatter(y_test, predictions)

# %%
plt.hist(y_test - predictions.reshape(91,1))
# Out:
# (array([ 1.,  0.,  1.,  2.,  5., 26., 40.,  6.,  5.,  5.]),
#  array([-912.93554688, -764.95908203, -616.98261719, -469.00615234,
#         -321.0296875 , -173.05322266,  -25.07675781,  122.89970703,
#          270.87617187,  418.85263672,  566.82910156]),
#  <BarContainer object of 10 artists>)

# %%
print('MAE:', metrics.mean_absolute_error(y_test, predictions))
print('MSE:', metrics.mean_squared_error(y_test, predictions))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, predictions)))
# Out:
# MAE: 143.0161897428743
# MSE: 45348.435112007865
# RMSE: 212.9517201433411

# %% [markdown]
# ### XGBoost

# %% [markdown]
# #### Treino e Previsão

# %%
import xgboost as xgb

# %%
params = {'max_depth': [4,5,6,7], 'n_estimators': [50, 100, 250, 400, 500, 600, 750, 1000],
              'learning_rate': [0.001, 0.0025, 0.005, 0.0075, 0.01], 'min_child_weight': [1, 5, 10], 
              'gamma': [0.5, 1, 1.5, 2, 5]
}
clf = xgb.XGBRegressor(use_label_encoder =False)

# %%
grid = GridSearchCV(clf, params, cv=KFold(n_splits=10), n_jobs=1, verbose=1, return_train_score=True, scoring='neg_mean_absolute_error', refit=True)

# %%
grid.fit(X_train,y_train)
# Out:
# Fitting 10 folds for each of 2400 candidates, totalling 24000 fits
# GridSearchCV(cv=KFold(n_splits=10, random_state=None, shuffle=False),
#              estimator=XGBRegressor(base_score=None, booster=None,
#                                     callbacks=None, colsample_bylevel=None,
#                                     colsample_bynode=None,
#                                     colsample_bytree=None,
#                                     early_stopping_rounds=None,
#                                     enable_categorical=False, eval_metric=None,
#                                     gamma=None, gpu_id=None, grow_policy=None,
#                                     importance_type=None,
#                                     interaction_constra...
#                                     n_jobs=None, num_parallel_tree=None,
#                                     predictor=None, random_state=None,
#                                     reg_alpha=None, reg_lambda=None, ...),
#              n_jobs=1,
#              param_grid={'gamma': [0.5, 1, 1.5, 2, 5],
#                          'learning_rate': [0.001, 0.0025, 0.005, 0.0075, 0.01],
#                          'max_depth': [4, 5, 6, 7],
#                          'min_child_weight': [1, 5, 10],
#                          'n_estimators': [50, 100, 250, 400, 500, 600, 750,
#                                           1000]},
#              return_train_score=True, scoring='neg_mean_absolute_error',
#              verbose=1)

# %%
print(f'The best parameters are: {grid.best_params_}')
print(f'The best score that we got is: {grid.best_score_}')
# Out:
# The best parameters are: {'gamma': 0.5, 'learning_rate': 0.0075, 'max_depth': 4, 'min_child_weight': 10, 'n_estimators': 600}
# The best score that we got is: -127.81855355721932

# %%
predictions = grid.predict(X_test)
predictions
# Out:
# array([1952.9495, 1878.958 , 1870.7047, 1945.9177, 1901.141 , 2149.709 ,
#        1985.9857, 1935.695 , 1946.6577, 1878.6487, 1931.745 , 1765.3185,
#        1925.6313, 1914.758 , 2026.8252, 1958.7957, 1977.3181, 1901.527 ,
#        1811.3716, 1595.1887, 1658.2606, 1854.626 , 2038.6702, 1941.7222,
#        1955.6298, 2023.2339, 1994.8055, 1618.5621, 1932.2015, 1941.5801,
#        1894.9287, 1944.0826, 1925.2642, 1953.8934, 1966.3132, 1899.2998,
#        1935.7418, 1914.2368, 2033.1682, 1754.7869, 1934.8298, 1887.1359,
#        1649.711 , 1815.0776, 1875.0004, 1809.0717, 1953.5938, 1855.59  ,
#        1937.3458, 1963.9697, 1876.4271, 1946.6586, 1909.4581, 2010.1222,
#        2011.0289, 2005.3939, 2022.5594, 1850.7256, 1762.7598, 1934.4281,
#        1926.7699, 1804.9453, 1915.8394, 1930.257 , 1810.7665, 1773.2708,
#        1772.9535, 2011.6718, 2135.3022, 1942.0032, 1843.1918, 1753.0438,
#        1913.4081, 1915.5736, 1801.2012, 1605.289 , 1938.2747, 2038.5885,
#        1863.357 , 1958.5386, 2026.669 , 2108.199 , 1968.3723, 1852.7853,
#        1838.7252, 2000.0653, 1917.1714, 1770.9296, 1809.4639, 1821.5657,
#        1653.8795], dtype=float32)

# %% [markdown]
# #### Avaliação

# %%
plt.scatter(y_test, predictions)

# %%
plt.hist(y_test - predictions.reshape(91,1))
# Out:
# (array([ 1.,  0.,  0.,  1.,  6., 35., 31., 10.,  3.,  4.]),
#  array([-869.95349121, -721.94207764, -573.93066406, -425.91925049,
#         -277.90783691, -129.89642334,   18.11499023,  166.12640381,
#          314.13781738,  462.14923096,  610.16064453]),
#  <BarContainer object of 10 artists>)

# %%
print('MAE:', metrics.mean_absolute_error(y_test, predictions))
print('MSE:', metrics.mean_squared_error(y_test, predictions))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, predictions)))
# Out:
# MAE: 130.82261171445742
# MSE: 40005.29095761691
# RMSE: 200.01322695666133
